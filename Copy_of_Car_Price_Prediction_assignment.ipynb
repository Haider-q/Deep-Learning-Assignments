# %% [markdown]
# # Car Price Prediction::

# %% [markdown]
# Download dataset from this link:
#
# https://www.kaggle.com/hellbuoy/car-price-prediction

# %% [markdown]
# # Problem Statement::

# %% [markdown]
# A Chinese automobile company Geely Auto aspires to enter the US market by setting up their manufacturing unit there and producing cars locally to give competition to their US and European counterparts.
#
# They have contracted an automobile consulting company to understand the factors on which the pricing of cars depends. Specifically, they want to understand the factors affecting the pricing of cars in the American market, since those may be very different from the Chinese market. The company wants to know:
#
# Which variables are significant in predicting the price of a car
# How well those variables describe the price of a car
# Based on various market surveys, the consulting firm has gathered a large data set of different types of cars across the America market.
#
# # task::
# We are required to model the price of cars with the available independent variables. It will be used by the management to understand how exactly the prices vary with the independent variables. They can accordingly manipulate the design of the cars, the business strategy etc. to meet certain price levels. Further, the model will be a good way for management to understand the pricing dynamics of a new market.

# %% [markdown]
# # WORKFLOW ::

# %% [markdown]
# 1.Load Data
#
# 2.Check Missing Values ( If Exist ; Fill each record with mean of its feature )
#
# 3.Split into 50% Training(Samples,Labels) , 30% Test(Samples,Labels) and 20% Validation Data(Samples,Labels).
#
# 4.Model : input Layer (No. of features ), 3 hidden layers including 10,8,6 unit & Output Layer with activation function relu/tanh (check by experiment).
#
# 5.Compilation Step (Note : Its a Regression problem , select loss , metrics according to it)
# 6.Train the Model with Epochs (100) and validate it
#
# 7.If the model gets overfit tune your model by changing the units , No. of layers , activation function , epochs , add dropout layer or add Regularizer according to the need .
#
# 8.Evaluation Step
#
# 9.Prediction

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import numpy as np
import pandas as pd

car_data = pd.read_csv('/content/drive/MyDrive/myassignment/CarPrice_Assignment.csv')

# %%
import tensorflow as tf

car_data.head()
# Out:
#    car_ID  symboling                   CarName  ... citympg highwaympg    price
# 0       1          3        alfa-romero giulia  ...      21         27  13495.0
# 1       2          3       alfa-romero stelvio  ...      21         27  16500.0
# 2       3          1  alfa-romero Quadrifoglio  ...      19         26  16500.0
# 3       4          2               audi 100 ls  ...      24         30  13950.0
# 4       5          2                audi 100ls  ...      18         22  17450.0
#
# [5 rows x 26 columns]

# %%
car_data['CarName'].unique()
# Out:
# array(['alfa-romero giulia', 'alfa-romero stelvio',
#        'alfa-romero Quadrifoglio', 'audi 100 ls', 'audi 100ls',
#        'audi fox', 'audi 5000', 'audi 4000', 'audi 5000s (diesel)',
#        'bmw 320i', 'bmw x1', 'bmw x3', 'bmw z4', 'bmw x4', 'bmw x5',
#        'chevrolet impala', 'chevrolet monte carlo', 'chevrolet vega 2300',
#        'dodge rampage', 'dodge challenger se', 'dodge d200',
#        'dodge monaco (sw)', 'dodge colt hardtop', 'dodge colt (sw)',
#        'dodge coronet custom', 'dodge dart custom',
#        'dodge coronet custom (sw)', 'honda civic', 'honda civic cvcc',
#        'honda accord cvcc', 'honda accord lx', 'honda civic 1500 gl',
#        'honda accord', 'honda civic 1300', 'honda prelude',
#        'honda civic (auto)', 'isuzu MU-X', 'isuzu D-Max ',
#        'isuzu D-Max V-Cross', 'jaguar xj', 'jaguar xf', 'jaguar xk',
#        'maxda rx3', 'maxda glc deluxe', 'mazda rx2 coupe', 'mazda rx-4',
#        'mazda glc deluxe', 'mazda 626', 'mazda glc', 'mazda rx-7 gs',
#        'mazda glc 4', 'mazda glc custom l', 'mazda glc custom',
#        'buick electra 225 custom', 'buick century luxus (sw)',
#        'buick century', 'buick skyhawk', 'buick opel isuzu deluxe',
#        'buick skylark', 'buick century special',
#        'buick regal sport coupe (turbo)', 'mercury cougar',
#        'mitsubishi mirage', 'mitsubishi lancer', 'mitsubishi outlander',
#        'mitsubishi g4', 'mitsubishi mirage g4', 'mitsubishi montero',
#        'mitsubishi pajero', 'Nissan versa', 'nissan gt-r', 'nissan rogue',
#        'nissan latio', 'nissan titan', 'nissan leaf', 'nissan juke',
#        'nissan note', 'nissan clipper', 'nissan nv200', 'nissan dayz',
#        'nissan fuga', 'nissan otti', 'nissan teana', 'nissan kicks',
#        'peugeot 504', 'peugeot 304', 'peugeot 504 (sw)', 'peugeot 604sl',
#        'peugeot 505s turbo diesel', 'plymouth fury iii',
#        'plymouth cricket', 'plymouth satellite custom (sw)',
#        'plymouth fury gran sedan', 'plymouth valiant', 'plymouth duster',
#        'porsche macan', 'porcshce panamera', 'porsche cayenne',
#        'porsche boxter', 'renault 12tl', 'renault 5 gtl', 'saab 99e',
#        'saab 99le', 'saab 99gle', 'subaru', 'subaru dl', 'subaru brz',
#        'subaru baja', 'subaru r1', 'subaru r2', 'subaru trezia',
#        'subaru tribeca', 'toyota corona mark ii', 'toyota corona',
#        'toyota corolla 1200', 'toyota corona hardtop',
#        'toyota corolla 1600 (sw)', 'toyota carina', 'toyota mark ii',
#        'toyota corolla', 'toyota corolla liftback',
#        'toyota celica gt liftback', 'toyota corolla tercel',
#        'toyota corona liftback', 'toyota starlet', 'toyota tercel',
#        'toyota cressida', 'toyota celica gt', 'toyouta tercel',
#        'vokswagen rabbit', 'volkswagen 1131 deluxe sedan',
#        'volkswagen model 111', 'volkswagen type 3', 'volkswagen 411 (sw)',
#        'volkswagen super beetle', 'volkswagen dasher', 'vw dasher',
#        'vw rabbit', 'volkswagen rabbit', 'volkswagen rabbit custom',
#        'volvo 145e (sw)', 'volvo 144ea', 'volvo 244dl', 'volvo 245',
#        'volvo 264gl', 'volvo diesel', 'volvo 246'], dtype=object)

# %%
np.where(car_data.applymap(lambda x: x ==''))
# Out:
# (array([], dtype=int64), array([], dtype=int64))

# %%
car_data.isnull().any()
# Out:
# car_ID              False
# symboling           False
# CarName             False
# fueltype            False
# aspiration          False
# doornumber          False
# carbody             False
# drivewheel          False
# enginelocation      False
# wheelbase           False
# carlength           False
# carwidth            False
# carheight           False
# curbweight          False
# enginetype          False
# cylindernumber      False
# enginesize          False
# fuelsystem          False
# boreratio           False
# stroke              False
# compressionratio    False
# horsepower          False
# peakrpm             False
# citympg             False
# highwaympg          False
# price               False
# dtype: bool

# %%
car_data.iloc[3,2] = 'audi 100ls'

# %%
car_data.dtypes
# Out:
# car_ID                int64
# symboling             int64
# CarName              object
# fueltype             object
# aspiration           object
# doornumber           object
# carbody              object
# drivewheel           object
# enginelocation       object
# wheelbase           float64
# carlength           float64
# carwidth            float64
# carheight           float64
# curbweight            int64
# enginetype           object
# cylindernumber       object
# enginesize            int64
# fuelsystem           object
# boreratio           float64
# stroke              float64
# compressionratio    float64
# horsepower            int64
# peakrpm               int64
# citympg               int64
# highwaympg            int64
# price               float64
# dtype: object

# %%
car_data.drop(columns=['car_ID'], inplace=True)

# %%
car_data.columns
# Out:
# Index(['symboling', 'CarName', 'fueltype', 'aspiration', 'doornumber',
#        'carbody', 'drivewheel', 'enginelocation', 'wheelbase', 'carlength',
#        'carwidth', 'carheight', 'curbweight', 'enginetype', 'cylindernumber',
#        'enginesize', 'fuelsystem', 'boreratio', 'stroke', 'compressionratio',
#        'horsepower', 'peakrpm', 'citympg', 'highwaympg', 'price'],
#       dtype='object')

# %%
final_car = pd.get_dummies(car_data, columns=['CarName','symboling','fueltype',	'aspiration',	'doornumber',	'carbody',	'drivewheel',	
                                              'enginelocation',	'enginetype',	'cylindernumber',	'fuelsystem'], drop_first = True)

# %%
final_car.head()
# Out:
#    wheelbase  carlength  ...  fuelsystem_spdi  fuelsystem_spfi
# 0       88.6      168.8  ...                0                0
# 1       88.6      168.8  ...                0                0
# 2       94.5      171.2  ...                0                0
# 3       99.8      176.6  ...                0                0
# 4       99.4      176.6  ...                0                0
#
# [5 rows x 193 columns]

# %%
final_car.describe()
# Out:
#         wheelbase   carlength  ...  fuelsystem_spdi  fuelsystem_spfi
# count  205.000000  205.000000  ...       205.000000       205.000000
# mean    98.756585  174.049268  ...         0.043902         0.004878
# std      6.021776   12.337289  ...         0.205380         0.069843
# min     86.600000  141.100000  ...         0.000000         0.000000
# 25%     94.500000  166.300000  ...         0.000000         0.000000
# 50%     97.000000  173.200000  ...         0.000000         0.000000
# 75%    102.400000  183.100000  ...         0.000000         0.000000
# max    120.900000  208.100000  ...         1.000000         1.000000
#
# [8 rows x 193 columns]

# %%
np.random.seed(11111)
msk = np.random.rand(len(final_car)) < 0.72
train_total = final_car[msk]
test_total = final_car[~msk]

# %%
print(len(train_total))
print(len(test_total))
# Out:
# 141
# 64

# %%
train_total.head(10)
# Out:
#     wheelbase  carlength  ...  fuelsystem_spdi  fuelsystem_spfi
# 1        88.6      168.8  ...                0                0
# 2        94.5      171.2  ...                0                0
# 3        99.8      176.6  ...                0                0
# 4        99.4      176.6  ...                0                0
# 5        99.8      177.3  ...                0                0
# 6       105.8      192.7  ...                0                0
# 7       105.8      192.7  ...                0                0
# 8       105.8      192.7  ...                0                0
# 9        99.5      178.2  ...                0                0
# 11      101.2      176.8  ...                0                0
#
# [10 rows x 193 columns]

# %%
train_total.describe()
# Out:
#         wheelbase   carlength  ...  fuelsystem_spdi  fuelsystem_spfi
# count  141.000000  141.000000  ...       141.000000       141.000000
# mean    98.692199  173.658156  ...         0.035461         0.007092
# std      6.005665   12.320089  ...         0.185601         0.084215
# min     86.600000  144.600000  ...         0.000000         0.000000
# 25%     94.500000  166.300000  ...         0.000000         0.000000
# 50%     96.500000  172.400000  ...         0.000000         0.000000
# 75%    102.400000  180.300000  ...         0.000000         0.000000
# max    115.600000  202.600000  ...         1.000000         1.000000
#
# [8 rows x 193 columns]

# %%
print(train_total.dtypes)
# Out:
# wheelbase          float64
# carlength          float64
# carwidth           float64
# carheight          float64
# curbweight           int64
#                     ...
# fuelsystem_idi       uint8
# fuelsystem_mfi       uint8
# fuelsystem_mpfi      uint8
# fuelsystem_spdi      uint8
# fuelsystem_spfi      uint8
# Length: 193, dtype: object

# %%
train_label = train_total.loc[:,'price']
test_label = test_total.loc[:,'price']

# %%
train_label
# Out:
# 1      16500.0
# 2      16500.0
# 3      13950.0
# 4      17450.0
# 5      15250.0
#         ...
# 200    16845.0
# 201    19045.0
# 202    21485.0
# 203    22470.0
# 204    22625.0
# Name: price, Length: 141, dtype: float64

# %%
test_data = test_total.drop(columns = ['price'])
train_data = train_total.drop(columns = ['price'])

# %%
train_data.shape[1]
# Out:
# 192

# %%
train_data
# Out:
#      wheelbase  carlength  ...  fuelsystem_spdi  fuelsystem_spfi
# 1         88.6      168.8  ...                0                0
# 2         94.5      171.2  ...                0                0
# 3         99.8      176.6  ...                0                0
# 4         99.4      176.6  ...                0                0
# 5         99.8      177.3  ...                0                0
# ..         ...        ...  ...              ...              ...
# 200      109.1      188.8  ...                0                0
# 201      109.1      188.8  ...                0                0
# 202      109.1      188.8  ...                0                0
# 203      109.1      188.8  ...                0                0
# 204      109.1      188.8  ...                0                0
#
# [141 rows x 192 columns]

# %%
{train_data.columns.get_loc(c): c for idx, c in enumerate(train_data.columns)}
# Out:
# {0: 'wheelbase',
#  1: 'carlength',
#  2: 'carwidth',
#  3: 'carheight',
#  4: 'curbweight',
#  5: 'enginesize',
#  6: 'boreratio',
#  7: 'stroke',
#  8: 'compressionratio',
#  9: 'horsepower',
#  10: 'peakrpm',
#  11: 'citympg',
#  12: 'highwaympg',
#  13: 'CarName_alfa-romero Quadrifoglio',
#  14: 'CarName_alfa-romero giulia',
#  15: 'CarName_alfa-romero stelvio',
#  16: 'CarName_audi 100ls',
#  17: 'CarName_audi 4000',
#  18: 'CarName_audi 5000',
#  19: 'CarName_audi 5000s (diesel)',
#  20: 'CarName_audi fox',
#  21: 'CarName_bmw 320i',
#  22: 'CarName_bmw x1',
#  23: 'CarName_bmw x3',
#  24: 'CarName_bmw x4',
#  25: 'CarName_bmw x5',
#  26: 'CarName_bmw z4',
#  27: 'CarName_buick century',
#  28: 'CarName_buick century luxus (sw)',
#  29: 'CarName_buick century special',
#  30: 'CarName_buick electra 225 custom',
#  31: 'CarName_buick opel isuzu deluxe',
#  32: 'CarName_buick regal sport coupe (turbo)',
#  33: 'CarName_buick skyhawk',
#  34: 'CarName_buick skylark',
#  35: 'CarName_chevrolet impala',
#  36: 'CarName_chevrolet monte carlo',
#  37: 'CarName_chevrolet vega 2300',
#  38: 'CarName_dodge challenger se',
#  39: 'CarName_dodge colt (sw)',
#  40: 'CarName_dodge colt hardtop',
#  41: 'CarName_dodge coronet custom',
#  42: 'CarName_dodge coronet custom (sw)',
#  43: 'CarName_dodge d200',
#  44: 'CarName_dodge dart custom',
#  45: 'CarName_dodge monaco (sw)',
#  46: 'CarName_dodge rampage',
#  47: 'CarName_honda accord',
#  48: 'CarName_honda accord cvcc',
#  49: 'CarName_honda accord lx',
#  50: 'CarName_honda civic',
#  51: 'CarName_honda civic (auto)',
#  52: 'CarName_honda civic 1300',
#  53: 'CarName_honda civic 1500 gl',
#  54: 'CarName_honda civic cvcc',
#  55: 'CarName_honda prelude',
#  56: 'CarName_isuzu D-Max ',
#  57: 'CarName_isuzu D-Max V-Cross',
#  58: 'CarName_isuzu MU-X',
#  59: 'CarName_jaguar xf',
#  60: 'CarName_jaguar xj',
#  61: 'CarName_jaguar xk',
#  62: 'CarName_maxda glc deluxe',
#  63: 'CarName_maxda rx3',
#  64: 'CarName_mazda 626',
#  65: 'CarName_mazda glc',
#  66: 'CarName_mazda glc 4',
#  67: 'CarName_mazda glc custom',
#  68: 'CarName_mazda glc custom l',
#  69: 'CarName_mazda glc deluxe',
#  70: 'CarName_mazda rx-4',
#  71: 'CarName_mazda rx-7 gs',
#  72: 'CarName_mazda rx2 coupe',
#  73: 'CarName_mercury cougar',
#  74: 'CarName_mitsubishi g4',
#  75: 'CarName_mitsubishi lancer',
#  76: 'CarName_mitsubishi mirage',
#  77: 'CarName_mitsubishi mirage g4',
#  78: 'CarName_mitsubishi montero',
#  79: 'CarName_mitsubishi outlander',
#  80: 'CarName_mitsubishi pajero',
#  81: 'CarName_nissan clipper',
#  82: 'CarName_nissan dayz',
#  83: 'CarName_nissan fuga',
#  84: 'CarName_nissan gt-r',
#  85: 'CarName_nissan juke',
#  86: 'CarName_nissan kicks',
#  87: 'CarName_nissan latio',
#  88: 'CarName_nissan leaf',
#  89: 'CarName_nissan note',
#  90: 'CarName_nissan nv200',
#  91: 'CarName_nissan otti',
#  92: 'CarName_nissan rogue',
#  93: 'CarName_nissan teana',
#  94: 'CarName_nissan titan',
#  95: 'CarName_peugeot 304',
#  96: 'CarName_peugeot 504',
#  97: 'CarName_peugeot 504 (sw)',
#  98: 'CarName_peugeot 505s turbo diesel',
#  99: 'CarName_peugeot 604sl',
#  100: 'CarName_plymouth cricket',
#  101: 'CarName_plymouth duster',
#  102: 'CarName_plymouth fury gran sedan',
#  103: 'CarName_plymouth fury iii',
#  104: 'CarName_plymouth satellite custom (sw)',
#  105: 'CarName_plymouth valiant',
#  106: 'CarName_porcshce panamera',
#  107: 'CarName_porsche boxter',
#  108: 'CarName_porsche cayenne',
#  109: 'CarName_porsche macan',
#  110: 'CarName_renault 12tl',
#  111: 'CarName_renault 5 gtl',
#  112: 'CarName_saab 99e',
#  113: 'CarName_saab 99gle',
#  114: 'CarName_saab 99le',
#  115: 'CarName_subaru',
#  116: 'CarName_subaru baja',
#  117: 'CarName_subaru brz',
#  118: 'CarName_subaru dl',
#  119: 'CarName_subaru r1',
#  120: 'CarName_subaru r2',
#  121: 'CarName_subaru trezia',
#  122: 'CarName_subaru tribeca',
#  123: 'CarName_toyota carina',
#  124: 'CarName_toyota celica gt',
#  125: 'CarName_toyota celica gt liftback',
#  126: 'CarName_toyota corolla',
#  127: 'CarName_toyota corolla 1200',
#  128: 'CarName_toyota corolla 1600 (sw)',
#  129: 'CarName_toyota corolla liftback',
#  130: 'CarName_toyota corolla tercel',
#  131: 'CarName_toyota corona',
#  132: 'CarName_toyota corona hardtop',
#  133: 'CarName_toyota corona liftback',
#  134: 'CarName_toyota corona mark ii',
#  135: 'CarName_toyota cressida',
#  136: 'CarName_toyota mark ii',
#  137: 'CarName_toyota starlet',
#  138: 'CarName_toyota tercel',
#  139: 'CarName_toyouta tercel',
#  140: 'CarName_vokswagen rabbit',
#  141: 'CarName_volkswagen 1131 deluxe sedan',
#  142: 'CarName_volkswagen 411 (sw)',
#  143: 'CarName_volkswagen dasher',
#  144: 'CarName_volkswagen model 111',
#  145: 'CarName_volkswagen rabbit',
#  146: 'CarName_volkswagen rabbit custom',
#  147: 'CarName_volkswagen super beetle',
#  148: 'CarName_volkswagen type 3',
#  149: 'CarName_volvo 144ea',
#  150: 'CarName_volvo 145e (sw)',
#  151: 'CarName_volvo 244dl',
#  152: 'CarName_volvo 245',
#  153: 'CarName_volvo 246',
#  154: 'CarName_volvo 264gl',
#  155: 'CarName_volvo diesel',
#  156: 'CarName_vw dasher',
#  157: 'CarName_vw rabbit',
#  158: 'symboling_-1',
#  159: 'symboling_0',
#  160: 'symboling_1',
#  161: 'symboling_2',
#  162: 'symboling_3',
#  163: 'fueltype_gas',
#  164: 'aspiration_turbo',
#  165: 'doornumber_two',
#  166: 'carbody_hardtop',
#  167: 'carbody_hatchback',
#  168: 'carbody_sedan',
#  169: 'carbody_wagon',
#  170: 'drivewheel_fwd',
#  171: 'drivewheel_rwd',
#  172: 'enginelocation_rear',
#  173: 'enginetype_dohcv',
#  174: 'enginetype_l',
#  175: 'enginetype_ohc',
#  176: 'enginetype_ohcf',
#  177: 'enginetype_ohcv',
#  178: 'enginetype_rotor',
#  179: 'cylindernumber_five',
#  180: 'cylindernumber_four',
#  181: 'cylindernumber_six',
#  182: 'cylindernumber_three',
#  183: 'cylindernumber_twelve',
#  184: 'cylindernumber_two',
#  185: 'fuelsystem_2bbl',
#  186: 'fuelsystem_4bbl',
#  187: 'fuelsystem_idi',
#  188: 'fuelsystem_mfi',
#  189: 'fuelsystem_mpfi',
#  190: 'fuelsystem_spdi',
#  191: 'fuelsystem_spfi'}

# %%
mean = train_data.iloc[:,0:13].mean(axis=0)
train_data.iloc[:,0:13] -= mean
std = train_data.iloc[:,0:13].std(axis=0)
train_data.iloc[:,0:13] /= std
test_data.iloc[:,0:13] -= mean
test_data.iloc[:,0:13] /= std

# %%
mean
# Out:
# wheelbase             98.692199
# carlength            173.658156
# carwidth              65.875887
# carheight             53.648227
# curbweight          2546.787234
# enginesize           125.666667
# boreratio              3.324184
# stroke                 3.256809
# compressionratio      10.070355
# horsepower           103.702128
# peakrpm             5143.971631
# citympg               25.113475
# highwaympg            30.581560
# dtype: float64

# %%
std
# Out:
# wheelbase             6.005665
# carlength            12.320089
# carwidth              2.188604
# carheight             2.508204
# curbweight          529.769152
# enginesize           41.733451
# boreratio             0.266123
# stroke                0.296387
# compressionratio      3.868579
# horsepower           38.424275
# peakrpm             474.472458
# citympg               6.509435
# highwaympg            6.734937
# dtype: float64

# %%
mean_label = train_label.mean()
train_label -= mean_label
std_label = train_label.std()
train_label /= std_label
test_label -= mean_label
test_label /= std_label

# %%
test_data.head(10)
# Out:
#     wheelbase  carlength  ...  fuelsystem_spdi  fuelsystem_spfi
# 0   -1.680447  -0.394328  ...                0                0
# 10   0.417573   0.255018  ...                0                0
# 14   0.800544   1.245271  ...                0                0
# 15   0.800544   1.245271  ...                0                0
# 18  -1.713748  -2.642688  ...                0                0
# 26  -0.831248  -1.327763  ...                0                0
# 27  -0.831248  -1.327763  ...                0                0
# 32  -0.831248  -1.920291  ...                0                0
# 34  -0.831248  -1.920291  ...                0                0
# 38  -0.365022  -0.499847  ...                0                0
#
# [10 rows x 192 columns]

# %%
print(mean_label)
# Out:
# 13379.132390070921

# %%
std_label
# Out:
# 8189.4945680106175

# %%
test = np.array(test_data.iloc[:]).astype('float32')

train = np.array(train_data.iloc[:]).astype('float32')

test_l= np.array(test_label.astype('float32'))

train_l= np.array(train_label.astype('float32'))

# %% [markdown]
# # Models section

# %%
from keras import models
from keras import layers
def build_model(act):
  model = models.Sequential()
  model.add(layers.Dense(128, activation= act,input_shape=(train.shape[1],)))
  model.add(layers.Dense(64, activation= act))
  model.add(layers.Dense(32, activation= act))
  model.add(layers.Dense(1))
  model.compile(optimizer='rmsprop', loss='mse', metrics=['mae'])
  return model

# %%
build_model('relu').summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 128)               24704
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dense_2 (Dense)              (None, 32)                2080
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 35,073
# Trainable params: 35,073
# Non-trainable params: 0
# _________________________________________________________________

# %%
build_model('tanh').summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_4 (Dense)              (None, 128)               24704
# _________________________________________________________________
# dense_5 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dense_6 (Dense)              (None, 32)                2080
# _________________________________________________________________
# dense_7 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 35,073
# Trainable params: 35,073
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras import regularizers
def build_model_regular(act):
  model = models.Sequential()
  model.add(layers.Dense(10, activation= act,kernel_regularizer= regularizers.l1_l2(l1=0.001, l2=0.001),input_shape=(train.shape[1],)))
  model.add(layers.Dense(8, activation= act,kernel_regularizer= regularizers.l1_l2(l1=0.001, l2=0.001)))
  model.add(layers.Dense(6, activation= act,kernel_regularizer= regularizers.l1_l2(l1=0.001, l2=0.001)))
  model.add(layers.Dense(1))
  model.compile(optimizer='rmsprop', loss='mse', metrics=['mae'])
  return model

# %%
build_model('tanh').summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_8 (Dense)              (None, 128)               24704
# _________________________________________________________________
# dense_9 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dense_10 (Dense)             (None, 32)                2080
# _________________________________________________________________
# dense_11 (Dense)             (None, 1)                 33
# =================================================================
# Total params: 35,073
# Trainable params: 35,073
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras import regularizers
def build_model_drop(act):
  model = models.Sequential()
  model.add(layers.Dense(10, activation= act,input_shape=(train.shape[1],)))
  model.add(layers.Dropout(0.2))
  model.add(layers.Dense(8, activation= act))
  model.add(layers.Dropout(0.2))
  model.add(layers.Dense(6, activation= act))
  model.add(layers.Dropout(0.2))
  model.add(layers.Dense(1))
  model.compile(optimizer='rmsprop', loss='mse', metrics=['mae'])
  return model

# %%
build_model_drop('relu').summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_12 (Dense)             (None, 10)                1930
# _________________________________________________________________
# dropout (Dropout)            (None, 10)                0
# _________________________________________________________________
# dense_13 (Dense)             (None, 8)                 88
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 8)                 0
# _________________________________________________________________
# dense_14 (Dense)             (None, 6)                 54
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 6)                 0
# _________________________________________________________________
# dense_15 (Dense)             (None, 1)                 7
# =================================================================
# Total params: 2,079
# Trainable params: 2,079
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # K Fold validation section

# %%
import numpy as np
k =  4
num_val_samples = len(train) // k
num_epochs = 100
all_scores_relu = []
for i in range(k):
  print('processing fold #', i)
  val_data = train[i * num_val_samples: (i + 1) * num_val_samples]
  val_targets = train_l[i * num_val_samples: (i + 1) * num_val_samples]
  partial_train_data = np.concatenate([train[:i * num_val_samples],train[(i + 1) * num_val_samples:]],  axis=0)
  # print(partial_train_data)
  partial_train_targets = np.concatenate([train_l[:i * num_val_samples],train_l[(i + 1) * num_val_samples:]],axis=0)
  model = build_model('relu')
  model.fit(partial_train_data, partial_train_targets,epochs=num_epochs, batch_size=1, verbose=0)
  val_mse, val_mae = model.evaluate(val_data, val_targets, verbose=0)
  all_scores_relu.append(val_mae)
# Out:
# processing fold # 0
# processing fold # 1
# processing fold # 2
# processing fold # 3

# %%
import numpy as np
k =  4
num_val_samples = len(train) // k
num_epochs = 100
all_scores_tanh = []
for i in range(k):
  print('processing fold #', i)
  val_data = train[i * num_val_samples: (i + 1) * num_val_samples]
  val_targets = train_l[i * num_val_samples: (i + 1) * num_val_samples]
  partial_train_data = np.concatenate([train[:i * num_val_samples],train[(i + 1) * num_val_samples:]],  axis=0)
  # print(partial_train_data)
  partial_train_targets = np.concatenate([train_l[:i * num_val_samples],train_l[(i + 1) * num_val_samples:]],axis=0)
  model = build_model('tanh')
  model.fit(partial_train_data, partial_train_targets,epochs=num_epochs, batch_size=1, verbose=0)
  val_mse, val_mae = model.evaluate(val_data, val_targets, verbose=0)
  all_scores_tanh.append(val_mae)
# Out:
# processing fold # 0
# WARNING:tensorflow:5 out of the last 9 calls to <function Model.make_test_function.<locals>.test_function at 0x7fb4a812bdd0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# processing fold # 1
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7fb4a6e39290> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# processing fold # 2
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7fb4a9b293b0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# processing fold # 3
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7fb4a9b29cb0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.

# %%
import numpy as np
k =  4
num_val_samples = len(train) // k
num_epochs = 100
all_scores_regular = []
for i in range(k):
  print('processing fold #', i)
  val_data = train[i * num_val_samples: (i + 1) * num_val_samples]
  val_targets = train_l[i * num_val_samples: (i + 1) * num_val_samples]
  partial_train_data = np.concatenate([train[:i * num_val_samples],train[(i + 1) * num_val_samples:]],  axis=0)
  # print(partial_train_data)
  partial_train_targets = np.concatenate([train_l[:i * num_val_samples],train_l[(i + 1) * num_val_samples:]],axis=0)
  model = build_model_regular('relu')
  model.fit(partial_train_data, partial_train_targets,epochs=num_epochs, batch_size=1, verbose=0)
  val_mse, val_mae = model.evaluate(val_data, val_targets, verbose=0)
  all_scores_regular.append(val_mae)
# Out:
# processing fold # 0
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7fb4a926c0e0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# processing fold # 1
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7fb4addaf5f0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# processing fold # 2
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7fb4addaf560> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# processing fold # 3
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7fb4a928d9e0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.

# %%
import numpy as np
k =  4
num_val_samples = len(train) // k
num_epochs = 100
all_scores_drop = []
for i in range(k):
  print('processing fold #', i)
  val_data = train[i * num_val_samples: (i + 1) * num_val_samples]
  val_targets = train_l[i * num_val_samples: (i + 1) * num_val_samples]
  partial_train_data = np.concatenate([train[:i * num_val_samples],train[(i + 1) * num_val_samples:]],  axis=0)
  # print(partial_train_data)
  partial_train_targets = np.concatenate([train_l[:i * num_val_samples],train_l[(i + 1) * num_val_samples:]],axis=0)
  model = build_model_drop('relu')
  model.fit(partial_train_data, partial_train_targets,epochs=num_epochs, batch_size=1, verbose=1)
  val_mse, val_mae = model.evaluate(val_data, val_targets, verbose=1)
  all_scores_drop.append(val_mae)
# Out:
# processing fold # 0
# Epoch 1/100
# 106/106 [==============================] - 1s 1ms/step - loss: 1.1874 - mae: 0.7605
# Epoch 2/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5721 - mae: 0.4786
# Epoch 3/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.6512 - mae: 0.5345
# Epoch 4/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.6484 - mae: 0.4917
# Epoch 5/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.8648 - mae: 0.5839
# Epoch 6/100
# 106/106 [==============================] - 0s 1ms/step - loss: 1.1530 - mae: 0.6343
# Epoch 7/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.7437 - mae: 0.5858
# Epoch 8/100
# 106/106 [==============================] - 0s 1ms/step - loss: 1.0287 - mae: 0.5797
# Epoch 9/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5649 - mae: 0.4629
# Epoch 10/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5154 - mae: 0.5107
# Epoch 11/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.6453 - mae: 0.4974
# Epoch 12/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5448 - mae: 0.4605
# Epoch 13/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.6703 - mae: 0.4590
# Epoch 14/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4644 - mae: 0.4640
# Epoch 15/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.6306 - mae: 0.4629
# Epoch 16/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4481 - mae: 0.4062
# Epoch 17/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.6495 - mae: 0.4734
# Epoch 18/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3873 - mae: 0.4051
# Epoch 19/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5617 - mae: 0.4973
# Epoch 20/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.6791 - mae: 0.5469
# Epoch 21/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.6710 - mae: 0.5066
# Epoch 22/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5229 - mae: 0.4261
# Epoch 23/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.6093 - mae: 0.4989
# Epoch 24/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3681 - mae: 0.3994
# Epoch 25/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.6049 - mae: 0.4841
# Epoch 26/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5378 - mae: 0.4387
# Epoch 27/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3140 - mae: 0.3723
# Epoch 28/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4942 - mae: 0.4634
# Epoch 29/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3880 - mae: 0.3788
# Epoch 30/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4255 - mae: 0.4013
# Epoch 31/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4661 - mae: 0.4234
# Epoch 32/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3725 - mae: 0.3875
# Epoch 33/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4435 - mae: 0.4236
# Epoch 34/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4216 - mae: 0.4686
# Epoch 35/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3364 - mae: 0.3503
# Epoch 36/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5238 - mae: 0.4792
# Epoch 37/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4283 - mae: 0.3917
# Epoch 38/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4859 - mae: 0.4746
# Epoch 39/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2832 - mae: 0.3349
# Epoch 40/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4070 - mae: 0.4238
# Epoch 41/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2154 - mae: 0.3150
# Epoch 42/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5278 - mae: 0.4808
# Epoch 43/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3772 - mae: 0.4131
# Epoch 44/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3692 - mae: 0.4110
# Epoch 45/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3390 - mae: 0.3612
# Epoch 46/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3793 - mae: 0.4048
# Epoch 47/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3362 - mae: 0.3532
# Epoch 48/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3612 - mae: 0.3785
# Epoch 49/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3488 - mae: 0.3799
# Epoch 50/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5176 - mae: 0.4469
# Epoch 51/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3805 - mae: 0.3848
# Epoch 52/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4392 - mae: 0.3965
# Epoch 53/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4724 - mae: 0.4358
# Epoch 54/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4794 - mae: 0.4757
# Epoch 55/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2800 - mae: 0.3366
# Epoch 56/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5887 - mae: 0.4675
# Epoch 57/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4671 - mae: 0.4643
# Epoch 58/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3105 - mae: 0.3823
# Epoch 59/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2411 - mae: 0.3599
# Epoch 60/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3922 - mae: 0.4172
# Epoch 61/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.7120 - mae: 0.4877
# Epoch 62/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1721 - mae: 0.2949
# Epoch 63/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1507 - mae: 0.2849
# Epoch 64/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1860 - mae: 0.2930
# Epoch 65/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3256 - mae: 0.3445
# Epoch 66/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2346 - mae: 0.3505
# Epoch 67/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3883 - mae: 0.4209
# Epoch 68/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2880 - mae: 0.3897
# Epoch 69/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4402 - mae: 0.4690
# Epoch 70/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5456 - mae: 0.4336
# Epoch 71/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2919 - mae: 0.3688
# Epoch 72/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3708 - mae: 0.4151
# Epoch 73/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2425 - mae: 0.3145
# Epoch 74/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3398 - mae: 0.3732
# Epoch 75/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3612 - mae: 0.4484
# Epoch 76/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1796 - mae: 0.2792
# Epoch 77/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2778 - mae: 0.3926
# Epoch 78/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4317 - mae: 0.4164
# Epoch 79/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3887 - mae: 0.3535
# Epoch 80/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2985 - mae: 0.3817
# Epoch 81/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4607 - mae: 0.4408
# Epoch 82/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5762 - mae: 0.4349
# Epoch 83/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2282 - mae: 0.3356
# Epoch 84/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3404 - mae: 0.4087
# Epoch 85/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1940 - mae: 0.2813
# Epoch 86/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1630 - mae: 0.2791
# Epoch 87/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2574 - mae: 0.3415
# Epoch 88/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3840 - mae: 0.4143
# Epoch 89/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1837 - mae: 0.3166
# Epoch 90/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2109 - mae: 0.2987
# Epoch 91/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4395 - mae: 0.4079
# Epoch 92/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5679 - mae: 0.3954
# Epoch 93/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3331 - mae: 0.3772
# Epoch 94/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4798 - mae: 0.4050
# Epoch 95/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.7134 - mae: 0.4401
# Epoch 96/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4057 - mae: 0.3940
# Epoch 97/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2620 - mae: 0.3348
# Epoch 98/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2862 - mae: 0.3436
# Epoch 99/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1960 - mae: 0.2879
# Epoch 100/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1840 - mae: 0.3009
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7fb4a9007f80> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 [==============================] - 0s 8ms/step - loss: 0.4097 - mae: 0.4887
# processing fold # 1
# Epoch 1/100
# 106/106 [==============================] - 1s 1ms/step - loss: 0.8146 - mae: 0.6256
# Epoch 2/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.6694 - mae: 0.4993
# Epoch 3/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.6505 - mae: 0.5427
# Epoch 4/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.8191 - mae: 0.5727
# Epoch 5/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4966 - mae: 0.4564
# Epoch 6/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4040 - mae: 0.4445
# Epoch 7/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5419 - mae: 0.4767
# Epoch 8/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5544 - mae: 0.4972
# Epoch 9/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3575 - mae: 0.4134
# Epoch 10/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.6407 - mae: 0.4887
# Epoch 11/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4748 - mae: 0.4812
# Epoch 12/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4610 - mae: 0.4415
# Epoch 13/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3984 - mae: 0.4315
# Epoch 14/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5519 - mae: 0.4888
# Epoch 15/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1536 - mae: 0.2902
# Epoch 16/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4071 - mae: 0.4234
# Epoch 17/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2877 - mae: 0.3852
# Epoch 18/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3344 - mae: 0.3929
# Epoch 19/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1544 - mae: 0.2868
# Epoch 20/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2392 - mae: 0.3286
# Epoch 21/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3077 - mae: 0.3505
# Epoch 22/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3946 - mae: 0.3915
# Epoch 23/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4293 - mae: 0.4077
# Epoch 24/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4617 - mae: 0.4686
# Epoch 25/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2362 - mae: 0.3769
# Epoch 26/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1394 - mae: 0.2676
# Epoch 27/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3453 - mae: 0.3970
# Epoch 28/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2543 - mae: 0.3100
# Epoch 29/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2798 - mae: 0.3560
# Epoch 30/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1911 - mae: 0.3222
# Epoch 31/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1884 - mae: 0.2750
# Epoch 32/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2273 - mae: 0.3207
# Epoch 33/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3627 - mae: 0.3682
# Epoch 34/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2583 - mae: 0.3174
# Epoch 35/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2223 - mae: 0.3324
# Epoch 36/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2187 - mae: 0.2991
# Epoch 37/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3043 - mae: 0.3550
# Epoch 38/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2545 - mae: 0.3434
# Epoch 39/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1993 - mae: 0.3357
# Epoch 40/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2360 - mae: 0.3369
# Epoch 41/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2233 - mae: 0.3141
# Epoch 42/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2056 - mae: 0.2920
# Epoch 43/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1499 - mae: 0.2636
# Epoch 44/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1559 - mae: 0.2598
# Epoch 45/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3969 - mae: 0.3596
# Epoch 46/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1199 - mae: 0.2643
# Epoch 47/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2344 - mae: 0.3286
# Epoch 48/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1871 - mae: 0.2861
# Epoch 49/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3974 - mae: 0.4068
# Epoch 50/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4996 - mae: 0.3951
# Epoch 51/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2466 - mae: 0.3236
# Epoch 52/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2709 - mae: 0.3444
# Epoch 53/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1658 - mae: 0.2931
# Epoch 54/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1750 - mae: 0.3054
# Epoch 55/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.6863 - mae: 0.4721
# Epoch 56/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3543 - mae: 0.3614
# Epoch 57/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2435 - mae: 0.3178
# Epoch 58/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2129 - mae: 0.3040
# Epoch 59/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1955 - mae: 0.2936
# Epoch 60/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3030 - mae: 0.3343
# Epoch 61/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1204 - mae: 0.2255
# Epoch 62/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2551 - mae: 0.2932
# Epoch 63/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2539 - mae: 0.3169
# Epoch 64/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1538 - mae: 0.2529
# Epoch 65/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1506 - mae: 0.2756
# Epoch 66/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1906 - mae: 0.2923
# Epoch 67/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1465 - mae: 0.2497
# Epoch 68/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2447 - mae: 0.2883
# Epoch 69/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1218 - mae: 0.2339
# Epoch 70/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4859 - mae: 0.3957
# Epoch 71/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2032 - mae: 0.3021
# Epoch 72/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3324 - mae: 0.3242
# Epoch 73/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1465 - mae: 0.2504
# Epoch 74/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2423 - mae: 0.3434
# Epoch 75/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1946 - mae: 0.2807
# Epoch 76/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1360 - mae: 0.2640
# Epoch 77/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3541 - mae: 0.3593
# Epoch 78/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1477 - mae: 0.2255
# Epoch 79/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3140 - mae: 0.2993
# Epoch 80/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1359 - mae: 0.2652
# Epoch 81/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1890 - mae: 0.2654
# Epoch 82/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.0811 - mae: 0.2026
# Epoch 83/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1711 - mae: 0.2721
# Epoch 84/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1374 - mae: 0.2762
# Epoch 85/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1749 - mae: 0.2618
# Epoch 86/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1098 - mae: 0.2251
# Epoch 87/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1738 - mae: 0.2640
# Epoch 88/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1576 - mae: 0.2494
# Epoch 89/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1697 - mae: 0.2108
# Epoch 90/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1353 - mae: 0.2360
# Epoch 91/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2613 - mae: 0.2640
# Epoch 92/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.0599 - mae: 0.1857
# Epoch 93/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2323 - mae: 0.2836
# Epoch 94/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.0755 - mae: 0.1982
# Epoch 95/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2676 - mae: 0.2950
# Epoch 96/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1660 - mae: 0.2710
# Epoch 97/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1378 - mae: 0.2390
# Epoch 98/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1815 - mae: 0.2749
# Epoch 99/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1759 - mae: 0.2281
# Epoch 100/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3547 - mae: 0.3397
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7fb4c2c760e0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 [==============================] - 0s 6ms/step - loss: 0.6966 - mae: 0.4856
# processing fold # 2
# Epoch 1/100
# 106/106 [==============================] - 1s 1ms/step - loss: 0.9485 - mae: 0.7227
# Epoch 2/100
# 106/106 [==============================] - 0s 1ms/step - loss: 1.0168 - mae: 0.7226
# Epoch 3/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5439 - mae: 0.5065
# Epoch 4/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3764 - mae: 0.4046
# Epoch 5/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4091 - mae: 0.4517
# Epoch 6/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2588 - mae: 0.3462
# Epoch 7/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4030 - mae: 0.4708
# Epoch 8/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2406 - mae: 0.3508
# Epoch 9/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3146 - mae: 0.4043
# Epoch 10/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2465 - mae: 0.3448
# Epoch 11/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2136 - mae: 0.3559
# Epoch 12/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1423 - mae: 0.2952
# Epoch 13/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3157 - mae: 0.3984
# Epoch 14/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2189 - mae: 0.3389
# Epoch 15/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3372 - mae: 0.3916
# Epoch 16/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3172 - mae: 0.3519
# Epoch 17/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4236 - mae: 0.3703
# Epoch 18/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4966 - mae: 0.3773
# Epoch 19/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2599 - mae: 0.3495
# Epoch 20/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4057 - mae: 0.3950
# Epoch 21/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5013 - mae: 0.4121
# Epoch 22/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1657 - mae: 0.2666
# Epoch 23/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2203 - mae: 0.2981
# Epoch 24/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2246 - mae: 0.3477
# Epoch 25/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3124 - mae: 0.3702
# Epoch 26/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1663 - mae: 0.2892
# Epoch 27/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3161 - mae: 0.3518
# Epoch 28/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4214 - mae: 0.4084
# Epoch 29/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3437 - mae: 0.3655
# Epoch 30/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3029 - mae: 0.3471
# Epoch 31/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1850 - mae: 0.3029
# Epoch 32/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2935 - mae: 0.3298
# Epoch 33/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4274 - mae: 0.3469
# Epoch 34/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2196 - mae: 0.3089
# Epoch 35/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3889 - mae: 0.3574
# Epoch 36/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2879 - mae: 0.3399
# Epoch 37/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3572 - mae: 0.3473
# Epoch 38/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2184 - mae: 0.2673
# Epoch 39/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5557 - mae: 0.4221
# Epoch 40/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3112 - mae: 0.3284
# Epoch 41/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1860 - mae: 0.2531
# Epoch 42/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2434 - mae: 0.3073
# Epoch 43/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1625 - mae: 0.2571
# Epoch 44/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3093 - mae: 0.3676
# Epoch 45/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3541 - mae: 0.3220
# Epoch 46/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5639 - mae: 0.4315
# Epoch 47/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2949 - mae: 0.3407
# Epoch 48/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2008 - mae: 0.2900
# Epoch 49/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2605 - mae: 0.3319
# Epoch 50/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2318 - mae: 0.3122
# Epoch 51/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2229 - mae: 0.2816
# Epoch 52/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2128 - mae: 0.2787
# Epoch 53/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2891 - mae: 0.3238
# Epoch 54/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2590 - mae: 0.3298
# Epoch 55/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2538 - mae: 0.3095
# Epoch 56/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1861 - mae: 0.2348
# Epoch 57/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1479 - mae: 0.2342
# Epoch 58/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1800 - mae: 0.2932
# Epoch 59/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2458 - mae: 0.2823
# Epoch 60/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1185 - mae: 0.2089
# Epoch 61/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1943 - mae: 0.2991
# Epoch 62/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2601 - mae: 0.3039
# Epoch 63/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1401 - mae: 0.2616
# Epoch 64/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3103 - mae: 0.3207
# Epoch 65/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3080 - mae: 0.3292
# Epoch 66/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1647 - mae: 0.2770
# Epoch 67/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1439 - mae: 0.2665
# Epoch 68/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1534 - mae: 0.2744
# Epoch 69/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1813 - mae: 0.2494
# Epoch 70/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1527 - mae: 0.2542
# Epoch 71/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2669 - mae: 0.2908
# Epoch 72/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2325 - mae: 0.3193
# Epoch 73/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2056 - mae: 0.3296
# Epoch 74/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2691 - mae: 0.3546
# Epoch 75/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1780 - mae: 0.2799
# Epoch 76/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2384 - mae: 0.2754
# Epoch 77/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2731 - mae: 0.3074
# Epoch 78/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.6290 - mae: 0.3737
# Epoch 79/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2300 - mae: 0.2749
# Epoch 80/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1473 - mae: 0.2491
# Epoch 81/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1217 - mae: 0.2275
# Epoch 82/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2098 - mae: 0.2916
# Epoch 83/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2115 - mae: 0.2937
# Epoch 84/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2222 - mae: 0.2674
# Epoch 85/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3139 - mae: 0.3047
# Epoch 86/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2700 - mae: 0.3765
# Epoch 87/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4191 - mae: 0.3522
# Epoch 88/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2572 - mae: 0.3106
# Epoch 89/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1832 - mae: 0.2910
# Epoch 90/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1965 - mae: 0.2518
# Epoch 91/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1379 - mae: 0.2564
# Epoch 92/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2516 - mae: 0.2891
# Epoch 93/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1108 - mae: 0.2284
# Epoch 94/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1056 - mae: 0.2298
# Epoch 95/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1153 - mae: 0.2258
# Epoch 96/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3568 - mae: 0.3537
# Epoch 97/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1947 - mae: 0.2485
# Epoch 98/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3372 - mae: 0.3444
# Epoch 99/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1100 - mae: 0.2006
# Epoch 100/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1684 - mae: 0.2606
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7fb4ae649050> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 [==============================] - 0s 6ms/step - loss: 0.3663 - mae: 0.3549
# processing fold # 3
# Epoch 1/100
# 106/106 [==============================] - 1s 1ms/step - loss: 0.8027 - mae: 0.6557
# Epoch 2/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.9223 - mae: 0.6464
# Epoch 3/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.7555 - mae: 0.5504
# Epoch 4/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.8325 - mae: 0.6329
# Epoch 5/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.7654 - mae: 0.6055
# Epoch 6/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.8240 - mae: 0.6530
# Epoch 7/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4843 - mae: 0.4884
# Epoch 8/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3755 - mae: 0.4385
# Epoch 9/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4757 - mae: 0.5223
# Epoch 10/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.6108 - mae: 0.5079
# Epoch 11/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3102 - mae: 0.4196
# Epoch 12/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2702 - mae: 0.3467
# Epoch 13/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4514 - mae: 0.4483
# Epoch 14/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4296 - mae: 0.4902
# Epoch 15/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2903 - mae: 0.4122
# Epoch 16/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4027 - mae: 0.4270
# Epoch 17/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4352 - mae: 0.4328
# Epoch 18/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4358 - mae: 0.4616
# Epoch 19/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5964 - mae: 0.4166
# Epoch 20/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5197 - mae: 0.4925
# Epoch 21/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5420 - mae: 0.4338
# Epoch 22/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3633 - mae: 0.4229
# Epoch 23/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2910 - mae: 0.3718
# Epoch 24/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3703 - mae: 0.3992
# Epoch 25/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5217 - mae: 0.4485
# Epoch 26/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3183 - mae: 0.3935
# Epoch 27/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3325 - mae: 0.4053
# Epoch 28/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4221 - mae: 0.3841
# Epoch 29/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5577 - mae: 0.4826
# Epoch 30/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5403 - mae: 0.4071
# Epoch 31/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1998 - mae: 0.2996
# Epoch 32/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3193 - mae: 0.4200
# Epoch 33/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2422 - mae: 0.3363
# Epoch 34/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2095 - mae: 0.3098
# Epoch 35/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2430 - mae: 0.3190
# Epoch 36/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4075 - mae: 0.4012
# Epoch 37/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3821 - mae: 0.4143
# Epoch 38/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3813 - mae: 0.3610
# Epoch 39/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2531 - mae: 0.3880
# Epoch 40/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3954 - mae: 0.4247
# Epoch 41/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4445 - mae: 0.3970
# Epoch 42/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3256 - mae: 0.3884
# Epoch 43/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2671 - mae: 0.3333
# Epoch 44/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5797 - mae: 0.4578
# Epoch 45/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4857 - mae: 0.3835
# Epoch 46/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2498 - mae: 0.3033
# Epoch 47/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2808 - mae: 0.3659
# Epoch 48/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5587 - mae: 0.4373
# Epoch 49/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3244 - mae: 0.3435
# Epoch 50/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2277 - mae: 0.3084
# Epoch 51/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3173 - mae: 0.3729
# Epoch 52/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3531 - mae: 0.3877
# Epoch 53/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3171 - mae: 0.3461
# Epoch 54/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4679 - mae: 0.4269
# Epoch 55/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2904 - mae: 0.3354
# Epoch 56/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2366 - mae: 0.3591
# Epoch 57/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2242 - mae: 0.3112
# Epoch 58/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2627 - mae: 0.3178
# Epoch 59/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2861 - mae: 0.3598
# Epoch 60/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.9138 - mae: 0.4972
# Epoch 61/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.6328 - mae: 0.4315
# Epoch 62/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2427 - mae: 0.3087
# Epoch 63/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3064 - mae: 0.3898
# Epoch 64/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3722 - mae: 0.3810
# Epoch 65/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2278 - mae: 0.3061
# Epoch 66/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2608 - mae: 0.3533
# Epoch 67/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2448 - mae: 0.3273
# Epoch 68/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1815 - mae: 0.2812
# Epoch 69/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2614 - mae: 0.3514
# Epoch 70/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1340 - mae: 0.2262
# Epoch 71/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2094 - mae: 0.2791
# Epoch 72/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2241 - mae: 0.3391
# Epoch 73/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2448 - mae: 0.3145
# Epoch 74/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2936 - mae: 0.3895
# Epoch 75/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2087 - mae: 0.3085
# Epoch 76/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1502 - mae: 0.2645
# Epoch 77/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2405 - mae: 0.3228
# Epoch 78/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2788 - mae: 0.3594
# Epoch 79/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2095 - mae: 0.3050
# Epoch 80/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1560 - mae: 0.2869
# Epoch 81/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1657 - mae: 0.2916
# Epoch 82/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3331 - mae: 0.3442
# Epoch 83/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1679 - mae: 0.2528
# Epoch 84/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3842 - mae: 0.3886
# Epoch 85/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2336 - mae: 0.2881
# Epoch 86/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3911 - mae: 0.3672
# Epoch 87/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1866 - mae: 0.3240
# Epoch 88/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3711 - mae: 0.3426
# Epoch 89/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2497 - mae: 0.2978
# Epoch 90/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1668 - mae: 0.2850
# Epoch 91/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2263 - mae: 0.3517
# Epoch 92/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2274 - mae: 0.3285
# Epoch 93/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2551 - mae: 0.3471
# Epoch 94/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3125 - mae: 0.3702
# Epoch 95/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1477 - mae: 0.2753
# Epoch 96/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2605 - mae: 0.3338
# Epoch 97/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2682 - mae: 0.3392
# Epoch 98/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4296 - mae: 0.3662
# Epoch 99/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2407 - mae: 0.3428
# Epoch 100/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1366 - mae: 0.2386
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7fb4a926c8c0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 [==============================] - 0s 8ms/step - loss: 0.2385 - mae: 0.3479

# %% [markdown]
# # Scores

# %%
all_scores_relu
# Out:
# [0.3649823069572449,
#  0.3233698308467865,
#  0.41489240527153015,
#  0.30037763714790344]

# %%
all_scores_tanh
# Out:
# [0.28761014342308044,
#  0.3103218376636505,
#  0.4227563142776489,
#  0.33338743448257446]

# %%
all_scores_regular
# Out:
# [0.2698203921318054, 0.381059855222702, 0.3220316469669342, 0.4697856903076172]

# %%
all_scores_drop
# Out:
# [0.48869526386260986,
#  0.4855841398239136,
#  0.3549272119998932,
#  0.34789711236953735]

# %% [markdown]
# # training on the training data

# %%
model_tanh = build_model('tanh')
model_tanh.fit(train, train_l,epochs= 100, batch_size=1, verbose=0)
test_mse_score, test_mae_score = model_tanh.evaluate(test, test_l)
# Out:
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7fb4aa49df80> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 [==============================] - 0s 6ms/step - loss: 0.0969 - mae: 0.2312

# %%
model_relu = build_model('relu')
model_relu.fit(train, train_l,epochs= 100, batch_size=1, verbose=0)
test_mse_score, test_mae_score = model_relu.evaluate(test, test_l)
# Out:
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7fb4a9197290> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 [==============================] - 0s 9ms/step - loss: 0.0918 - mae: 0.2380

# %%
model_regular = build_model_regular('relu')
model_regular.fit(train, train_l,epochs= 100, batch_size=1, verbose=0)
test_mse_score, test_mae_score = model_regular.evaluate(test, test_l)
# Out:
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7fb4a8dfc680> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 [==============================] - 0s 7ms/step - loss: 0.1014 - mae: 0.2121

# %%
model_drop = build_model_drop('relu')
model_drop.fit(train, train_l,epochs= 100, batch_size=1, verbose=0)
test_mse_score, test_mae_score = model_drop.evaluate(test, test_l)
# Out:
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7fb4a8dfc3b0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 [==============================] - 0s 7ms/step - loss: 0.2235 - mae: 0.3028

# %% [markdown]
# # Prediction Section

# %%
test_l
# Out:
# array([ 0.01414832,  0.3725343 ,  1.3658801 ,  2.122337  , -1.004718  ,
#        -0.7045773 , -0.5886972 , -0.97443527, -0.763189  , -0.52312535,
#        -0.05301089, -0.3704908 , -0.5449216 , -0.80397296, -0.5536523 ,
#        -0.26059392,  0.6062484 ,  1.4864004 ,  2.5404336 ,  3.367835  ,
#        -0.8779702 , -0.09159691,  0.18192424, -0.7802841 , -0.50065756,
#        -0.9622245 , -0.6813769 , -0.5409531 ,  0.01463675,  0.12453365,
#         0.46643507, -0.1806134 ,  0.2687428 ,  0.4299249 ,  0.45129374,
#        -0.07511237,  2.3382235 ,  2.200547  , -0.49870384,  0.20280465,
#         0.26019526, -0.68430746, -0.7224051 , -0.65524584, -0.98066276,
#        -0.7889537 , -0.7547636 , -0.6888255 , -0.6277716 , -0.4983375 ,
#        -0.6020069 , -0.4139611 , -0.22347318, -0.54107517,  0.28217462,
#        -0.68430746, -0.6574438 , -0.59638995, -0.01027321,  0.056886  ,
#        -0.1329914 , -0.05362143,  0.3181964 ,  0.6155285 ], dtype=float32)

# %%
def predict(model, m):
  print(f" the actual price was : {test_l[m]* std_label + mean_label} " )
  return(f" the predicted price was : {(model.predict(test[m:m+1].reshape(1,test.shape[1]))) * std_label + mean_label} ")

# %%
x_tanh = predict(model_tanh,2)
x_tanh
# Out:
#  the actual price was : 24565.000309357743
# ' the predicted price was : [[20743.922]] '

# %%
x_relu = predict(model_relu,2)
x_relu
# Out:
#  the actual price was : 24565.000309357743
# ' the predicted price was : [[22013.045]] '

# %%
x_regular = predict(model_regular,2)
x_regular
# Out:
#  the actual price was : 24565.000309357743
# ' the predicted price was : [[24972.809]] '

# %%
x_drop = predict(model_drop,2)
x_drop
# Out:
#  the actual price was : 24565.000309357743
# ' the predicted price was : [[16223.05]] '

# %%
def plot_fn(mod):
  y_true = test_l* std_label + mean_label
  y_pred = mod.predict(test) * std_label + mean_label
  return y_true , y_pred.flatten()

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
def plotting(mod, label):
  y_true, y_pred = plot_fn(mod)
  coef = np.polyfit(y_true,y_pred,1)
  poly1d_fn = np.poly1d(coef) 
  # poly1d_fn is now a function which takes in x and returns an estimate for y
  plt.figure()
  plt.plot(y_true,y_pred, 'yo', y_true, poly1d_fn(y_true), '--k')
  plt.title(label)
  plt.xlabel('Thousand Dollar True' )
  plt.ylabel('Thousand Dollar Predictions' )
  plt.xlim(0, 50000)
  plt.ylim(0, 50000)

# %%
plot_list = []
for i,j in enumerate([model_relu, model_tanh, model_regular, model_drop]):
  list_name = ['model_relu', 'model_tanh', 'model_regular', 'model_drop']
  plot_list.append(plotting(j,list_name[i]))
# Out:
# WARNING:tensorflow:5 out of the last 5 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fb4a923bdd0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 7 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fb4aa406680> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:7 out of the last 9 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fb4a6eb7dd0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:8 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fb4a6eb7680> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
