# %% [markdown]
# <a href="https://colab.research.google.com/github/Haider-q/Deep-Learning-Assignments/blob/main/Car_Price_Prediction_assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Car Price Prediction::

# %% [markdown]
# Download dataset from this link:
#
# https://www.kaggle.com/hellbuoy/car-price-prediction

# %% [markdown]
# # Problem Statement::

# %% [markdown]
# A Chinese automobile company Geely Auto aspires to enter the US market by setting up their manufacturing unit there and producing cars locally to give competition to their US and European counterparts.
#
# They have contracted an automobile consulting company to understand the factors on which the pricing of cars depends. Specifically, they want to understand the factors affecting the pricing of cars in the American market, since those may be very different from the Chinese market. The company wants to know:
#
# Which variables are significant in predicting the price of a car
# How well those variables describe the price of a car
# Based on various market surveys, the consulting firm has gathered a large data set of different types of cars across the America market.
#
# # task::
# We are required to model the price of cars with the available independent variables. It will be used by the management to understand how exactly the prices vary with the independent variables. They can accordingly manipulate the design of the cars, the business strategy etc. to meet certain price levels. Further, the model will be a good way for management to understand the pricing dynamics of a new market.

# %% [markdown]
# # WORKFLOW ::

# %% [markdown]
# 1.Load Data
#
# 2.Check Missing Values ( If Exist ; Fill each record with mean of its feature )
#
# 3.Split into 50% Training(Samples,Labels) , 30% Test(Samples,Labels) and 20% Validation Data(Samples,Labels).
#
# 4.Model : input Layer (No. of features ), 3 hidden layers including 10,8,6 unit & Output Layer with activation function relu/tanh (check by experiment).
#
# 5.Compilation Step (Note : Its a Regression problem , select loss , metrics according to it)
# 6.Train the Model with Epochs (100) and validate it
#
# 7.If the model gets overfit tune your model by changing the units , No. of layers , activation function , epochs , add dropout layer or add Regularizer according to the need .
#
# 8.Evaluation Step
#
# 9.Prediction

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd

car_data = pd.read_csv('/content/drive/MyDrive/myassignment/CarPrice_Assignment.csv')

# %%
import tensorflow as tf

car_data.head()
# Out:
#    car_ID  symboling                   CarName  ... citympg highwaympg    price
# 0       1          3        alfa-romero giulia  ...      21         27  13495.0
# 1       2          3       alfa-romero stelvio  ...      21         27  16500.0
# 2       3          1  alfa-romero Quadrifoglio  ...      19         26  16500.0
# 3       4          2               audi 100 ls  ...      24         30  13950.0
# 4       5          2                audi 100ls  ...      18         22  17450.0
#
# [5 rows x 26 columns]

# %%
car_data['CarName'].unique()
# Out:
# array(['alfa-romero giulia', 'alfa-romero stelvio',
#        'alfa-romero Quadrifoglio', 'audi 100 ls', 'audi 100ls',
#        'audi fox', 'audi 5000', 'audi 4000', 'audi 5000s (diesel)',
#        'bmw 320i', 'bmw x1', 'bmw x3', 'bmw z4', 'bmw x4', 'bmw x5',
#        'chevrolet impala', 'chevrolet monte carlo', 'chevrolet vega 2300',
#        'dodge rampage', 'dodge challenger se', 'dodge d200',
#        'dodge monaco (sw)', 'dodge colt hardtop', 'dodge colt (sw)',
#        'dodge coronet custom', 'dodge dart custom',
#        'dodge coronet custom (sw)', 'honda civic', 'honda civic cvcc',
#        'honda accord cvcc', 'honda accord lx', 'honda civic 1500 gl',
#        'honda accord', 'honda civic 1300', 'honda prelude',
#        'honda civic (auto)', 'isuzu MU-X', 'isuzu D-Max ',
#        'isuzu D-Max V-Cross', 'jaguar xj', 'jaguar xf', 'jaguar xk',
#        'maxda rx3', 'maxda glc deluxe', 'mazda rx2 coupe', 'mazda rx-4',
#        'mazda glc deluxe', 'mazda 626', 'mazda glc', 'mazda rx-7 gs',
#        'mazda glc 4', 'mazda glc custom l', 'mazda glc custom',
#        'buick electra 225 custom', 'buick century luxus (sw)',
#        'buick century', 'buick skyhawk', 'buick opel isuzu deluxe',
#        'buick skylark', 'buick century special',
#        'buick regal sport coupe (turbo)', 'mercury cougar',
#        'mitsubishi mirage', 'mitsubishi lancer', 'mitsubishi outlander',
#        'mitsubishi g4', 'mitsubishi mirage g4', 'mitsubishi montero',
#        'mitsubishi pajero', 'Nissan versa', 'nissan gt-r', 'nissan rogue',
#        'nissan latio', 'nissan titan', 'nissan leaf', 'nissan juke',
#        'nissan note', 'nissan clipper', 'nissan nv200', 'nissan dayz',
#        'nissan fuga', 'nissan otti', 'nissan teana', 'nissan kicks',
#        'peugeot 504', 'peugeot 304', 'peugeot 504 (sw)', 'peugeot 604sl',
#        'peugeot 505s turbo diesel', 'plymouth fury iii',
#        'plymouth cricket', 'plymouth satellite custom (sw)',
#        'plymouth fury gran sedan', 'plymouth valiant', 'plymouth duster',
#        'porsche macan', 'porcshce panamera', 'porsche cayenne',
#        'porsche boxter', 'renault 12tl', 'renault 5 gtl', 'saab 99e',
#        'saab 99le', 'saab 99gle', 'subaru', 'subaru dl', 'subaru brz',
#        'subaru baja', 'subaru r1', 'subaru r2', 'subaru trezia',
#        'subaru tribeca', 'toyota corona mark ii', 'toyota corona',
#        'toyota corolla 1200', 'toyota corona hardtop',
#        'toyota corolla 1600 (sw)', 'toyota carina', 'toyota mark ii',
#        'toyota corolla', 'toyota corolla liftback',
#        'toyota celica gt liftback', 'toyota corolla tercel',
#        'toyota corona liftback', 'toyota starlet', 'toyota tercel',
#        'toyota cressida', 'toyota celica gt', 'toyouta tercel',
#        'vokswagen rabbit', 'volkswagen 1131 deluxe sedan',
#        'volkswagen model 111', 'volkswagen type 3', 'volkswagen 411 (sw)',
#        'volkswagen super beetle', 'volkswagen dasher', 'vw dasher',
#        'vw rabbit', 'volkswagen rabbit', 'volkswagen rabbit custom',
#        'volvo 145e (sw)', 'volvo 144ea', 'volvo 244dl', 'volvo 245',
#        'volvo 264gl', 'volvo diesel', 'volvo 246'], dtype=object)

# %%
np.where(car_data.applymap(lambda x: x ==''))
# Out:
# (array([], dtype=int64), array([], dtype=int64))

# %%
car_data.isnull().any()
# Out:
# car_ID              False
# symboling           False
# CarName             False
# fueltype            False
# aspiration          False
# doornumber          False
# carbody             False
# drivewheel          False
# enginelocation      False
# wheelbase           False
# carlength           False
# carwidth            False
# carheight           False
# curbweight          False
# enginetype          False
# cylindernumber      False
# enginesize          False
# fuelsystem          False
# boreratio           False
# stroke              False
# compressionratio    False
# horsepower          False
# peakrpm             False
# citympg             False
# highwaympg          False
# price               False
# dtype: bool

# %%
car_data.iloc[3,2] = 'audi 100ls'

# %%
car_data.dtypes
# Out:
# car_ID                int64
# symboling             int64
# CarName              object
# fueltype             object
# aspiration           object
# doornumber           object
# carbody              object
# drivewheel           object
# enginelocation       object
# wheelbase           float64
# carlength           float64
# carwidth            float64
# carheight           float64
# curbweight            int64
# enginetype           object
# cylindernumber       object
# enginesize            int64
# fuelsystem           object
# boreratio           float64
# stroke              float64
# compressionratio    float64
# horsepower            int64
# peakrpm               int64
# citympg               int64
# highwaympg            int64
# price               float64
# dtype: object

# %%
car_data.drop(columns=['car_ID'], inplace=True)

# %%
car_data.columns
# Out:
# Index(['symboling', 'CarName', 'fueltype', 'aspiration', 'doornumber',
#        'carbody', 'drivewheel', 'enginelocation', 'wheelbase', 'carlength',
#        'carwidth', 'carheight', 'curbweight', 'enginetype', 'cylindernumber',
#        'enginesize', 'fuelsystem', 'boreratio', 'stroke', 'compressionratio',
#        'horsepower', 'peakrpm', 'citympg', 'highwaympg', 'price'],
#       dtype='object')

# %%
final_car = pd.get_dummies(car_data, columns=['CarName','symboling','fueltype',	'aspiration',	'doornumber',	'carbody',	'drivewheel',	
                                              'enginelocation',	'enginetype',	'cylindernumber',	'fuelsystem'], drop_first = True)

# %%
final_car.head()
# Out:
#    wheelbase  carlength  ...  fuelsystem_spdi  fuelsystem_spfi
# 0       88.6      168.8  ...                0                0
# 1       88.6      168.8  ...                0                0
# 2       94.5      171.2  ...                0                0
# 3       99.8      176.6  ...                0                0
# 4       99.4      176.6  ...                0                0
#
# [5 rows x 193 columns]

# %%
final_car.describe()
# Out:
#         wheelbase   carlength  ...  fuelsystem_spdi  fuelsystem_spfi
# count  205.000000  205.000000  ...       205.000000       205.000000
# mean    98.756585  174.049268  ...         0.043902         0.004878
# std      6.021776   12.337289  ...         0.205380         0.069843
# min     86.600000  141.100000  ...         0.000000         0.000000
# 25%     94.500000  166.300000  ...         0.000000         0.000000
# 50%     97.000000  173.200000  ...         0.000000         0.000000
# 75%    102.400000  183.100000  ...         0.000000         0.000000
# max    120.900000  208.100000  ...         1.000000         1.000000
#
# [8 rows x 193 columns]

# %%
np.random.seed(11111)
msk = np.random.rand(len(final_car)) < 0.72
train_total = final_car[msk]
test_total = final_car[~msk]

# %%
print(len(train_total))
print(len(test_total))
# Out:
# 141
# 64

# %%
train_total.head(10)
# Out:
#     wheelbase  carlength  ...  fuelsystem_spdi  fuelsystem_spfi
# 1        88.6      168.8  ...                0                0
# 2        94.5      171.2  ...                0                0
# 3        99.8      176.6  ...                0                0
# 4        99.4      176.6  ...                0                0
# 5        99.8      177.3  ...                0                0
# 6       105.8      192.7  ...                0                0
# 7       105.8      192.7  ...                0                0
# 8       105.8      192.7  ...                0                0
# 9        99.5      178.2  ...                0                0
# 11      101.2      176.8  ...                0                0
#
# [10 rows x 193 columns]

# %%
train_total.describe()
# Out:
#         wheelbase   carlength  ...  fuelsystem_spdi  fuelsystem_spfi
# count  141.000000  141.000000  ...       141.000000       141.000000
# mean    98.692199  173.658156  ...         0.035461         0.007092
# std      6.005665   12.320089  ...         0.185601         0.084215
# min     86.600000  144.600000  ...         0.000000         0.000000
# 25%     94.500000  166.300000  ...         0.000000         0.000000
# 50%     96.500000  172.400000  ...         0.000000         0.000000
# 75%    102.400000  180.300000  ...         0.000000         0.000000
# max    115.600000  202.600000  ...         1.000000         1.000000
#
# [8 rows x 193 columns]

# %%
print(train_total.dtypes)
# Out:
# wheelbase          float64
# carlength          float64
# carwidth           float64
# carheight          float64
# curbweight           int64
#                     ...
# fuelsystem_idi       uint8
# fuelsystem_mfi       uint8
# fuelsystem_mpfi      uint8
# fuelsystem_spdi      uint8
# fuelsystem_spfi      uint8
# Length: 193, dtype: object

# %%
train_label = train_total.loc[:,'price']
test_label = test_total.loc[:,'price']

# %%
train_label
# Out:
# 1      16500.0
# 2      16500.0
# 3      13950.0
# 4      17450.0
# 5      15250.0
#         ...
# 200    16845.0
# 201    19045.0
# 202    21485.0
# 203    22470.0
# 204    22625.0
# Name: price, Length: 141, dtype: float64

# %%
test_data = test_total.drop(columns = ['price'])
train_data = train_total.drop(columns = ['price'])

# %%
train_data.shape[1]
# Out:
# 192

# %%
train_data
# Out:
#      wheelbase  carlength  ...  fuelsystem_spdi  fuelsystem_spfi
# 1         88.6      168.8  ...                0                0
# 2         94.5      171.2  ...                0                0
# 3         99.8      176.6  ...                0                0
# 4         99.4      176.6  ...                0                0
# 5         99.8      177.3  ...                0                0
# ..         ...        ...  ...              ...              ...
# 200      109.1      188.8  ...                0                0
# 201      109.1      188.8  ...                0                0
# 202      109.1      188.8  ...                0                0
# 203      109.1      188.8  ...                0                0
# 204      109.1      188.8  ...                0                0
#
# [141 rows x 192 columns]

# %%
{train_data.columns.get_loc(c): c for idx, c in enumerate(train_data.columns)}
# Out:
# {0: 'wheelbase',
#  1: 'carlength',
#  2: 'carwidth',
#  3: 'carheight',
#  4: 'curbweight',
#  5: 'enginesize',
#  6: 'boreratio',
#  7: 'stroke',
#  8: 'compressionratio',
#  9: 'horsepower',
#  10: 'peakrpm',
#  11: 'citympg',
#  12: 'highwaympg',
#  13: 'CarName_alfa-romero Quadrifoglio',
#  14: 'CarName_alfa-romero giulia',
#  15: 'CarName_alfa-romero stelvio',
#  16: 'CarName_audi 100ls',
#  17: 'CarName_audi 4000',
#  18: 'CarName_audi 5000',
#  19: 'CarName_audi 5000s (diesel)',
#  20: 'CarName_audi fox',
#  21: 'CarName_bmw 320i',
#  22: 'CarName_bmw x1',
#  23: 'CarName_bmw x3',
#  24: 'CarName_bmw x4',
#  25: 'CarName_bmw x5',
#  26: 'CarName_bmw z4',
#  27: 'CarName_buick century',
#  28: 'CarName_buick century luxus (sw)',
#  29: 'CarName_buick century special',
#  30: 'CarName_buick electra 225 custom',
#  31: 'CarName_buick opel isuzu deluxe',
#  32: 'CarName_buick regal sport coupe (turbo)',
#  33: 'CarName_buick skyhawk',
#  34: 'CarName_buick skylark',
#  35: 'CarName_chevrolet impala',
#  36: 'CarName_chevrolet monte carlo',
#  37: 'CarName_chevrolet vega 2300',
#  38: 'CarName_dodge challenger se',
#  39: 'CarName_dodge colt (sw)',
#  40: 'CarName_dodge colt hardtop',
#  41: 'CarName_dodge coronet custom',
#  42: 'CarName_dodge coronet custom (sw)',
#  43: 'CarName_dodge d200',
#  44: 'CarName_dodge dart custom',
#  45: 'CarName_dodge monaco (sw)',
#  46: 'CarName_dodge rampage',
#  47: 'CarName_honda accord',
#  48: 'CarName_honda accord cvcc',
#  49: 'CarName_honda accord lx',
#  50: 'CarName_honda civic',
#  51: 'CarName_honda civic (auto)',
#  52: 'CarName_honda civic 1300',
#  53: 'CarName_honda civic 1500 gl',
#  54: 'CarName_honda civic cvcc',
#  55: 'CarName_honda prelude',
#  56: 'CarName_isuzu D-Max ',
#  57: 'CarName_isuzu D-Max V-Cross',
#  58: 'CarName_isuzu MU-X',
#  59: 'CarName_jaguar xf',
#  60: 'CarName_jaguar xj',
#  61: 'CarName_jaguar xk',
#  62: 'CarName_maxda glc deluxe',
#  63: 'CarName_maxda rx3',
#  64: 'CarName_mazda 626',
#  65: 'CarName_mazda glc',
#  66: 'CarName_mazda glc 4',
#  67: 'CarName_mazda glc custom',
#  68: 'CarName_mazda glc custom l',
#  69: 'CarName_mazda glc deluxe',
#  70: 'CarName_mazda rx-4',
#  71: 'CarName_mazda rx-7 gs',
#  72: 'CarName_mazda rx2 coupe',
#  73: 'CarName_mercury cougar',
#  74: 'CarName_mitsubishi g4',
#  75: 'CarName_mitsubishi lancer',
#  76: 'CarName_mitsubishi mirage',
#  77: 'CarName_mitsubishi mirage g4',
#  78: 'CarName_mitsubishi montero',
#  79: 'CarName_mitsubishi outlander',
#  80: 'CarName_mitsubishi pajero',
#  81: 'CarName_nissan clipper',
#  82: 'CarName_nissan dayz',
#  83: 'CarName_nissan fuga',
#  84: 'CarName_nissan gt-r',
#  85: 'CarName_nissan juke',
#  86: 'CarName_nissan kicks',
#  87: 'CarName_nissan latio',
#  88: 'CarName_nissan leaf',
#  89: 'CarName_nissan note',
#  90: 'CarName_nissan nv200',
#  91: 'CarName_nissan otti',
#  92: 'CarName_nissan rogue',
#  93: 'CarName_nissan teana',
#  94: 'CarName_nissan titan',
#  95: 'CarName_peugeot 304',
#  96: 'CarName_peugeot 504',
#  97: 'CarName_peugeot 504 (sw)',
#  98: 'CarName_peugeot 505s turbo diesel',
#  99: 'CarName_peugeot 604sl',
#  100: 'CarName_plymouth cricket',
#  101: 'CarName_plymouth duster',
#  102: 'CarName_plymouth fury gran sedan',
#  103: 'CarName_plymouth fury iii',
#  104: 'CarName_plymouth satellite custom (sw)',
#  105: 'CarName_plymouth valiant',
#  106: 'CarName_porcshce panamera',
#  107: 'CarName_porsche boxter',
#  108: 'CarName_porsche cayenne',
#  109: 'CarName_porsche macan',
#  110: 'CarName_renault 12tl',
#  111: 'CarName_renault 5 gtl',
#  112: 'CarName_saab 99e',
#  113: 'CarName_saab 99gle',
#  114: 'CarName_saab 99le',
#  115: 'CarName_subaru',
#  116: 'CarName_subaru baja',
#  117: 'CarName_subaru brz',
#  118: 'CarName_subaru dl',
#  119: 'CarName_subaru r1',
#  120: 'CarName_subaru r2',
#  121: 'CarName_subaru trezia',
#  122: 'CarName_subaru tribeca',
#  123: 'CarName_toyota carina',
#  124: 'CarName_toyota celica gt',
#  125: 'CarName_toyota celica gt liftback',
#  126: 'CarName_toyota corolla',
#  127: 'CarName_toyota corolla 1200',
#  128: 'CarName_toyota corolla 1600 (sw)',
#  129: 'CarName_toyota corolla liftback',
#  130: 'CarName_toyota corolla tercel',
#  131: 'CarName_toyota corona',
#  132: 'CarName_toyota corona hardtop',
#  133: 'CarName_toyota corona liftback',
#  134: 'CarName_toyota corona mark ii',
#  135: 'CarName_toyota cressida',
#  136: 'CarName_toyota mark ii',
#  137: 'CarName_toyota starlet',
#  138: 'CarName_toyota tercel',
#  139: 'CarName_toyouta tercel',
#  140: 'CarName_vokswagen rabbit',
#  141: 'CarName_volkswagen 1131 deluxe sedan',
#  142: 'CarName_volkswagen 411 (sw)',
#  143: 'CarName_volkswagen dasher',
#  144: 'CarName_volkswagen model 111',
#  145: 'CarName_volkswagen rabbit',
#  146: 'CarName_volkswagen rabbit custom',
#  147: 'CarName_volkswagen super beetle',
#  148: 'CarName_volkswagen type 3',
#  149: 'CarName_volvo 144ea',
#  150: 'CarName_volvo 145e (sw)',
#  151: 'CarName_volvo 244dl',
#  152: 'CarName_volvo 245',
#  153: 'CarName_volvo 246',
#  154: 'CarName_volvo 264gl',
#  155: 'CarName_volvo diesel',
#  156: 'CarName_vw dasher',
#  157: 'CarName_vw rabbit',
#  158: 'symboling_-1',
#  159: 'symboling_0',
#  160: 'symboling_1',
#  161: 'symboling_2',
#  162: 'symboling_3',
#  163: 'fueltype_gas',
#  164: 'aspiration_turbo',
#  165: 'doornumber_two',
#  166: 'carbody_hardtop',
#  167: 'carbody_hatchback',
#  168: 'carbody_sedan',
#  169: 'carbody_wagon',
#  170: 'drivewheel_fwd',
#  171: 'drivewheel_rwd',
#  172: 'enginelocation_rear',
#  173: 'enginetype_dohcv',
#  174: 'enginetype_l',
#  175: 'enginetype_ohc',
#  176: 'enginetype_ohcf',
#  177: 'enginetype_ohcv',
#  178: 'enginetype_rotor',
#  179: 'cylindernumber_five',
#  180: 'cylindernumber_four',
#  181: 'cylindernumber_six',
#  182: 'cylindernumber_three',
#  183: 'cylindernumber_twelve',
#  184: 'cylindernumber_two',
#  185: 'fuelsystem_2bbl',
#  186: 'fuelsystem_4bbl',
#  187: 'fuelsystem_idi',
#  188: 'fuelsystem_mfi',
#  189: 'fuelsystem_mpfi',
#  190: 'fuelsystem_spdi',
#  191: 'fuelsystem_spfi'}

# %%
mean = train_data.iloc[:,0:13].mean(axis=0)
train_data.iloc[:,0:13] -= mean
std = train_data.iloc[:,0:13].std(axis=0)
train_data.iloc[:,0:13] /= std
test_data.iloc[:,0:13] -= mean
test_data.iloc[:,0:13] /= std

# %%
mean
# Out:
# wheelbase             98.692199
# carlength            173.658156
# carwidth              65.875887
# carheight             53.648227
# curbweight          2546.787234
# enginesize           125.666667
# boreratio              3.324184
# stroke                 3.256809
# compressionratio      10.070355
# horsepower           103.702128
# peakrpm             5143.971631
# citympg               25.113475
# highwaympg            30.581560
# dtype: float64

# %%
std
# Out:
# wheelbase             6.005665
# carlength            12.320089
# carwidth              2.188604
# carheight             2.508204
# curbweight          529.769152
# enginesize           41.733451
# boreratio             0.266123
# stroke                0.296387
# compressionratio      3.868579
# horsepower           38.424275
# peakrpm             474.472458
# citympg               6.509435
# highwaympg            6.734937
# dtype: float64

# %%
mean_label = train_label.mean()
train_label -= mean_label
std_label = train_label.std()
train_label /= std_label
test_label -= mean_label
test_label /= std_label

# %%
test_data.head(10)
# Out:
#     wheelbase  carlength  ...  fuelsystem_spdi  fuelsystem_spfi
# 0   -1.680447  -0.394328  ...                0                0
# 10   0.417573   0.255018  ...                0                0
# 14   0.800544   1.245271  ...                0                0
# 15   0.800544   1.245271  ...                0                0
# 18  -1.713748  -2.642688  ...                0                0
# 26  -0.831248  -1.327763  ...                0                0
# 27  -0.831248  -1.327763  ...                0                0
# 32  -0.831248  -1.920291  ...                0                0
# 34  -0.831248  -1.920291  ...                0                0
# 38  -0.365022  -0.499847  ...                0                0
#
# [10 rows x 192 columns]

# %%
print(mean_label)
# Out:
# 13379.132390070921

# %%
std_label
# Out:
# 8189.4945680106175

# %%
test = np.array(test_data.iloc[:]).astype('float32')

train = np.array(train_data.iloc[:]).astype('float32')

test_l= np.array(test_label.astype('float32'))

train_l= np.array(train_label.astype('float32'))

# %% [markdown]
# # Models section

# %%
from keras import models
from keras import layers
def build_model(act):
  model = models.Sequential()
  model.add(layers.Dense(128, activation= act,input_shape=(train.shape[1],)))
  model.add(layers.Dense(64, activation= act))
  model.add(layers.Dense(32, activation= act))
  model.add(layers.Dense(1))
  model.compile(optimizer='rmsprop', loss='mse', metrics=['mae'])
  return model

# %%
build_model('relu').summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 128)               24704
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dense_2 (Dense)              (None, 32)                2080
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 35,073
# Trainable params: 35,073
# Non-trainable params: 0
# _________________________________________________________________

# %%
build_model('tanh').summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_4 (Dense)              (None, 128)               24704
# _________________________________________________________________
# dense_5 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dense_6 (Dense)              (None, 32)                2080
# _________________________________________________________________
# dense_7 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 35,073
# Trainable params: 35,073
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras import regularizers
def build_model_regular(act):
  model = models.Sequential()
  model.add(layers.Dense(10, activation= act,kernel_regularizer= regularizers.l1_l2(l1=0.001, l2=0.001),input_shape=(train.shape[1],)))
  model.add(layers.Dense(8, activation= act,kernel_regularizer= regularizers.l1_l2(l1=0.001, l2=0.001)))
  model.add(layers.Dense(6, activation= act,kernel_regularizer= regularizers.l1_l2(l1=0.001, l2=0.001)))
  model.add(layers.Dense(1))
  model.compile(optimizer='rmsprop', loss='mse', metrics=['mae'])
  return model

# %%
build_model('tanh').summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_8 (Dense)              (None, 128)               24704
# _________________________________________________________________
# dense_9 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dense_10 (Dense)             (None, 32)                2080
# _________________________________________________________________
# dense_11 (Dense)             (None, 1)                 33
# =================================================================
# Total params: 35,073
# Trainable params: 35,073
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras import regularizers
def build_model_drop(act):
  model = models.Sequential()
  model.add(layers.Dense(10, activation= act,input_shape=(train.shape[1],)))
  model.add(layers.Dropout(0.2))
  model.add(layers.Dense(8, activation= act))
  model.add(layers.Dropout(0.2))
  model.add(layers.Dense(6, activation= act))
  model.add(layers.Dropout(0.2))
  model.add(layers.Dense(1))
  model.compile(optimizer='rmsprop', loss='mse', metrics=['mae'])
  return model

# %%
build_model_drop('relu').summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_12 (Dense)             (None, 10)                1930
# _________________________________________________________________
# dropout (Dropout)            (None, 10)                0
# _________________________________________________________________
# dense_13 (Dense)             (None, 8)                 88
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 8)                 0
# _________________________________________________________________
# dense_14 (Dense)             (None, 6)                 54
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 6)                 0
# _________________________________________________________________
# dense_15 (Dense)             (None, 1)                 7
# =================================================================
# Total params: 2,079
# Trainable params: 2,079
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # K Fold validation section

# %%
import numpy as np
k =  4
num_val_samples = len(train) // k
num_epochs = 100
all_scores_relu = []
for i in range(k):
  print('processing fold #', i)
  val_data = train[i * num_val_samples: (i + 1) * num_val_samples]
  val_targets = train_l[i * num_val_samples: (i + 1) * num_val_samples]
  partial_train_data = np.concatenate([train[:i * num_val_samples],train[(i + 1) * num_val_samples:]],  axis=0)
  # print(partial_train_data)
  partial_train_targets = np.concatenate([train_l[:i * num_val_samples],train_l[(i + 1) * num_val_samples:]],axis=0)
  model = build_model('relu')
  model.fit(partial_train_data, partial_train_targets,epochs=num_epochs, batch_size=1, verbose=0)
  val_mse, val_mae = model.evaluate(val_data, val_targets, verbose=0)
  all_scores_relu.append(val_mae)
# Out:
# processing fold # 0
# processing fold # 1
# processing fold # 2
# processing fold # 3

# %%
import numpy as np
k =  4
num_val_samples = len(train) // k
num_epochs = 100
all_scores_tanh = []
for i in range(k):
  print('processing fold #', i)
  val_data = train[i * num_val_samples: (i + 1) * num_val_samples]
  val_targets = train_l[i * num_val_samples: (i + 1) * num_val_samples]
  partial_train_data = np.concatenate([train[:i * num_val_samples],train[(i + 1) * num_val_samples:]],  axis=0)
  # print(partial_train_data)
  partial_train_targets = np.concatenate([train_l[:i * num_val_samples],train_l[(i + 1) * num_val_samples:]],axis=0)
  model = build_model('tanh')
  model.fit(partial_train_data, partial_train_targets,epochs=num_epochs, batch_size=1, verbose=0)
  val_mse, val_mae = model.evaluate(val_data, val_targets, verbose=0)
  all_scores_tanh.append(val_mae)
# Out:
# processing fold # 0
# WARNING:tensorflow:5 out of the last 9 calls to <function Model.make_test_function.<locals>.test_function at 0x7f6d3b3529e0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# processing fold # 1
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7f6d3c52f050> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# processing fold # 2
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7f6d3f0ca050> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# processing fold # 3
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7f6d40e9c050> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.

# %%
import numpy as np
k =  4
num_val_samples = len(train) // k
num_epochs = 100
all_scores_regular = []
for i in range(k):
  print('processing fold #', i)
  val_data = train[i * num_val_samples: (i + 1) * num_val_samples]
  val_targets = train_l[i * num_val_samples: (i + 1) * num_val_samples]
  partial_train_data = np.concatenate([train[:i * num_val_samples],train[(i + 1) * num_val_samples:]],  axis=0)
  # print(partial_train_data)
  partial_train_targets = np.concatenate([train_l[:i * num_val_samples],train_l[(i + 1) * num_val_samples:]],axis=0)
  model = build_model_regular('relu')
  model.fit(partial_train_data, partial_train_targets,epochs=num_epochs, batch_size=1, verbose=0)
  val_mse, val_mae = model.evaluate(val_data, val_targets, verbose=0)
  all_scores_regular.append(val_mae)
# Out:
# processing fold # 0
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7f6d40eba440> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# processing fold # 1
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7f6d3a16db00> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# processing fold # 2
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7f6d38f26560> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# processing fold # 3
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7f6d38f06dd0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.

# %%
import numpy as np
k =  4
num_val_samples = len(train) // k
num_epochs = 100
all_scores_drop = []
for i in range(k):
  print('processing fold #', i)
  val_data = train[i * num_val_samples: (i + 1) * num_val_samples]
  val_targets = train_l[i * num_val_samples: (i + 1) * num_val_samples]
  partial_train_data = np.concatenate([train[:i * num_val_samples],train[(i + 1) * num_val_samples:]],  axis=0)
  # print(partial_train_data)
  partial_train_targets = np.concatenate([train_l[:i * num_val_samples],train_l[(i + 1) * num_val_samples:]],axis=0)
  model = build_model_drop('relu')
  model.fit(partial_train_data, partial_train_targets,epochs=num_epochs, batch_size=1, verbose=1)
  val_mse, val_mae = model.evaluate(val_data, val_targets, verbose=1)
  all_scores_drop.append(val_mae)
# Out:
# processing fold # 0
# Epoch 1/100
# 106/106 [==============================] - 1s 1ms/step - loss: 1.0207 - mae: 0.8026
# Epoch 2/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.7163 - mae: 0.6435
# Epoch 3/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.7032 - mae: 0.5800
# Epoch 4/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3499 - mae: 0.4510
# Epoch 5/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2771 - mae: 0.3623
# Epoch 6/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.6149 - mae: 0.5013
# Epoch 7/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4006 - mae: 0.4217
# Epoch 8/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2585 - mae: 0.3736
# Epoch 9/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.6145 - mae: 0.5060
# Epoch 10/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4281 - mae: 0.3779
# Epoch 11/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2453 - mae: 0.3472
# Epoch 12/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4418 - mae: 0.3725
# Epoch 13/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2817 - mae: 0.3342
# Epoch 14/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3722 - mae: 0.3557
# Epoch 15/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4069 - mae: 0.3719
# Epoch 16/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3290 - mae: 0.3519
# Epoch 17/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2440 - mae: 0.2768
# Epoch 18/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3347 - mae: 0.3752
# Epoch 19/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1980 - mae: 0.3297
# Epoch 20/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2960 - mae: 0.3669
# Epoch 21/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1756 - mae: 0.2766
# Epoch 22/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1505 - mae: 0.2674
# Epoch 23/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1960 - mae: 0.3315
# Epoch 24/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3634 - mae: 0.3636
# Epoch 25/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1891 - mae: 0.2832
# Epoch 26/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1728 - mae: 0.2642
# Epoch 27/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1785 - mae: 0.2940
# Epoch 28/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2502 - mae: 0.2864
# Epoch 29/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3400 - mae: 0.3558
# Epoch 30/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2043 - mae: 0.2833
# Epoch 31/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3525 - mae: 0.3558
# Epoch 32/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5658 - mae: 0.4245
# Epoch 33/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1562 - mae: 0.2307
# Epoch 34/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2042 - mae: 0.2903
# Epoch 35/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1465 - mae: 0.2656
# Epoch 36/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1774 - mae: 0.2738
# Epoch 37/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1560 - mae: 0.2697
# Epoch 38/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1273 - mae: 0.2250
# Epoch 39/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4859 - mae: 0.3815
# Epoch 40/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1998 - mae: 0.2802
# Epoch 41/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2290 - mae: 0.2395
# Epoch 42/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2796 - mae: 0.3391
# Epoch 43/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3044 - mae: 0.3234
# Epoch 44/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4198 - mae: 0.3729
# Epoch 45/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1871 - mae: 0.2446
# Epoch 46/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1523 - mae: 0.2619
# Epoch 47/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4200 - mae: 0.3673
# Epoch 48/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3837 - mae: 0.3884
# Epoch 49/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1081 - mae: 0.2350
# Epoch 50/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.6382 - mae: 0.4388
# Epoch 51/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1617 - mae: 0.2833
# Epoch 52/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1695 - mae: 0.2668
# Epoch 53/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2323 - mae: 0.2871
# Epoch 54/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5099 - mae: 0.3659
# Epoch 55/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1174 - mae: 0.2380
# Epoch 56/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3099 - mae: 0.3070
# Epoch 57/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3670 - mae: 0.3730
# Epoch 58/100
# 106/106 [==============================] - 0s 2ms/step - loss: 0.1137 - mae: 0.2153
# Epoch 59/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4020 - mae: 0.3461
# Epoch 60/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1412 - mae: 0.2713
# Epoch 61/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2300 - mae: 0.2552
# Epoch 62/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4087 - mae: 0.3669
# Epoch 63/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1573 - mae: 0.2858
# Epoch 64/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2084 - mae: 0.2624
# Epoch 65/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2498 - mae: 0.2809
# Epoch 66/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2681 - mae: 0.2932
# Epoch 67/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1496 - mae: 0.2525
# Epoch 68/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2610 - mae: 0.3264
# Epoch 69/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.0966 - mae: 0.1870
# Epoch 70/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1530 - mae: 0.2523
# Epoch 71/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2105 - mae: 0.2547
# Epoch 72/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1681 - mae: 0.2662
# Epoch 73/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.0956 - mae: 0.2048
# Epoch 74/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2090 - mae: 0.2834
# Epoch 75/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2794 - mae: 0.2964
# Epoch 76/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1462 - mae: 0.2586
# Epoch 77/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3352 - mae: 0.3435
# Epoch 78/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1528 - mae: 0.2618
# Epoch 79/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2210 - mae: 0.3193
# Epoch 80/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2113 - mae: 0.2693
# Epoch 81/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1342 - mae: 0.1990
# Epoch 82/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1012 - mae: 0.2163
# Epoch 83/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1606 - mae: 0.2486
# Epoch 84/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2559 - mae: 0.2670
# Epoch 85/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.0975 - mae: 0.1777
# Epoch 86/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1804 - mae: 0.2271
# Epoch 87/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1383 - mae: 0.2272
# Epoch 88/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1676 - mae: 0.2362
# Epoch 89/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1559 - mae: 0.2424
# Epoch 90/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1803 - mae: 0.2803
# Epoch 91/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2322 - mae: 0.2902
# Epoch 92/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1088 - mae: 0.1961
# Epoch 93/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1315 - mae: 0.2379
# Epoch 94/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1878 - mae: 0.2394
# Epoch 95/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2828 - mae: 0.3054
# Epoch 96/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2606 - mae: 0.2653
# Epoch 97/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1964 - mae: 0.2441
# Epoch 98/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1075 - mae: 0.2316
# Epoch 99/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1938 - mae: 0.2829
# Epoch 100/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1086 - mae: 0.2037
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7f6d385387a0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 [==============================] - 0s 7ms/step - loss: 0.4166 - mae: 0.4024
# processing fold # 1
# Epoch 1/100
# 106/106 [==============================] - 1s 1ms/step - loss: 0.8223 - mae: 0.7391
# Epoch 2/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5327 - mae: 0.5550
# Epoch 3/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5348 - mae: 0.5962
# Epoch 4/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5757 - mae: 0.5463
# Epoch 5/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3863 - mae: 0.4552
# Epoch 6/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5132 - mae: 0.4460
# Epoch 7/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3221 - mae: 0.4011
# Epoch 8/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4490 - mae: 0.4218
# Epoch 9/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4577 - mae: 0.4132
# Epoch 10/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3379 - mae: 0.4350
# Epoch 11/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2448 - mae: 0.3613
# Epoch 12/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3696 - mae: 0.3916
# Epoch 13/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1688 - mae: 0.3022
# Epoch 14/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1973 - mae: 0.3384
# Epoch 15/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2797 - mae: 0.3967
# Epoch 16/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1657 - mae: 0.2944
# Epoch 17/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1894 - mae: 0.2727
# Epoch 18/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2143 - mae: 0.3040
# Epoch 19/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2693 - mae: 0.3427
# Epoch 20/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3385 - mae: 0.3523
# Epoch 21/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1947 - mae: 0.2732
# Epoch 22/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1187 - mae: 0.2367
# Epoch 23/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3046 - mae: 0.3433
# Epoch 24/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1649 - mae: 0.2740
# Epoch 25/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1105 - mae: 0.2359
# Epoch 26/100
# 106/106 [==============================] - 0s 2ms/step - loss: 0.1637 - mae: 0.2658
# Epoch 27/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2637 - mae: 0.3064
# Epoch 28/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1670 - mae: 0.2822
# Epoch 29/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2511 - mae: 0.2868
# Epoch 30/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1331 - mae: 0.2609
# Epoch 31/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4579 - mae: 0.4081
# Epoch 32/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2095 - mae: 0.3019
# Epoch 33/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4617 - mae: 0.3800
# Epoch 34/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1453 - mae: 0.2482
# Epoch 35/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4765 - mae: 0.3940
# Epoch 36/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1457 - mae: 0.2815
# Epoch 37/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1928 - mae: 0.3061
# Epoch 38/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1398 - mae: 0.2420
# Epoch 39/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2502 - mae: 0.2857
# Epoch 40/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1518 - mae: 0.2618
# Epoch 41/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1151 - mae: 0.2306
# Epoch 42/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2389 - mae: 0.3445
# Epoch 43/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3918 - mae: 0.3476
# Epoch 44/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2100 - mae: 0.3168
# Epoch 45/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3852 - mae: 0.3848
# Epoch 46/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4126 - mae: 0.3238
# Epoch 47/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1167 - mae: 0.2221
# Epoch 48/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1297 - mae: 0.2861
# Epoch 49/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2807 - mae: 0.3365
# Epoch 50/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2348 - mae: 0.2976
# Epoch 51/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2629 - mae: 0.2797
# Epoch 52/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.0908 - mae: 0.2158
# Epoch 53/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1102 - mae: 0.2515
# Epoch 54/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1485 - mae: 0.2747
# Epoch 55/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2063 - mae: 0.3123
# Epoch 56/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2498 - mae: 0.2980
# Epoch 57/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4277 - mae: 0.3450
# Epoch 58/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1708 - mae: 0.2564
# Epoch 59/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1206 - mae: 0.2285
# Epoch 60/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4678 - mae: 0.3607
# Epoch 61/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1167 - mae: 0.2295
# Epoch 62/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2202 - mae: 0.3219
# Epoch 63/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1793 - mae: 0.2475
# Epoch 64/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1314 - mae: 0.2443
# Epoch 65/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1479 - mae: 0.2504
# Epoch 66/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1615 - mae: 0.2571
# Epoch 67/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1735 - mae: 0.2749
# Epoch 68/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2213 - mae: 0.2903
# Epoch 69/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.0906 - mae: 0.2194
# Epoch 70/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1196 - mae: 0.1877
# Epoch 71/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1146 - mae: 0.2228
# Epoch 72/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4625 - mae: 0.3496
# Epoch 73/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2799 - mae: 0.3100
# Epoch 74/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1648 - mae: 0.2487
# Epoch 75/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1690 - mae: 0.2676
# Epoch 76/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2155 - mae: 0.2720
# Epoch 77/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2604 - mae: 0.2950
# Epoch 78/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2949 - mae: 0.3085
# Epoch 79/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1682 - mae: 0.2524
# Epoch 80/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1423 - mae: 0.2485
# Epoch 81/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4013 - mae: 0.3826
# Epoch 82/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1073 - mae: 0.2221
# Epoch 83/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.0886 - mae: 0.1907
# Epoch 84/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1177 - mae: 0.2262
# Epoch 85/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1578 - mae: 0.2600
# Epoch 86/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.0770 - mae: 0.1860
# Epoch 87/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1449 - mae: 0.2321
# Epoch 88/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1601 - mae: 0.2564
# Epoch 89/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2006 - mae: 0.2657
# Epoch 90/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3347 - mae: 0.2859
# Epoch 91/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2163 - mae: 0.2577
# Epoch 92/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1279 - mae: 0.2270
# Epoch 93/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.0974 - mae: 0.2121
# Epoch 94/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1059 - mae: 0.2191
# Epoch 95/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2097 - mae: 0.2882
# Epoch 96/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3042 - mae: 0.2741
# Epoch 97/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1025 - mae: 0.2041
# Epoch 98/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1169 - mae: 0.2353
# Epoch 99/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3309 - mae: 0.2953
# Epoch 100/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2258 - mae: 0.3074
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7f6d46bc3dd0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 [==============================] - 0s 7ms/step - loss: 0.5809 - mae: 0.4575
# processing fold # 2
# Epoch 1/100
# 106/106 [==============================] - 1s 1ms/step - loss: 0.9409 - mae: 0.7622
# Epoch 2/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5673 - mae: 0.5895
# Epoch 3/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4851 - mae: 0.5685
# Epoch 4/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.6665 - mae: 0.5740
# Epoch 5/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3355 - mae: 0.4997
# Epoch 6/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4550 - mae: 0.4884
# Epoch 7/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5487 - mae: 0.4976
# Epoch 8/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3894 - mae: 0.4458
# Epoch 9/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2989 - mae: 0.3714
# Epoch 10/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3352 - mae: 0.3760
# Epoch 11/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3528 - mae: 0.3799
# Epoch 12/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3792 - mae: 0.4342
# Epoch 13/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4777 - mae: 0.4645
# Epoch 14/100
# 106/106 [==============================] - 0s 2ms/step - loss: 0.2973 - mae: 0.3974
# Epoch 15/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2489 - mae: 0.3175
# Epoch 16/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4168 - mae: 0.4234
# Epoch 17/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5166 - mae: 0.4588
# Epoch 18/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5323 - mae: 0.4532
# Epoch 19/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1856 - mae: 0.2909
# Epoch 20/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3468 - mae: 0.3508
# Epoch 21/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2777 - mae: 0.3406
# Epoch 22/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1703 - mae: 0.3054
# Epoch 23/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1513 - mae: 0.2894
# Epoch 24/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3162 - mae: 0.3895
# Epoch 25/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3244 - mae: 0.3304
# Epoch 26/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5195 - mae: 0.4329
# Epoch 27/100
# 106/106 [==============================] - 0s 2ms/step - loss: 0.4339 - mae: 0.4117
# Epoch 28/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1994 - mae: 0.2682
# Epoch 29/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3977 - mae: 0.3533
# Epoch 30/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2350 - mae: 0.3145
# Epoch 31/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1783 - mae: 0.3037
# Epoch 32/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2673 - mae: 0.3103
# Epoch 33/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3825 - mae: 0.3942
# Epoch 34/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3854 - mae: 0.3955
# Epoch 35/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2876 - mae: 0.3454
# Epoch 36/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3420 - mae: 0.3548
# Epoch 37/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1894 - mae: 0.2953
# Epoch 38/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2682 - mae: 0.3524
# Epoch 39/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1890 - mae: 0.3200
# Epoch 40/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1951 - mae: 0.2956
# Epoch 41/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2633 - mae: 0.3299
# Epoch 42/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3094 - mae: 0.3448
# Epoch 43/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4442 - mae: 0.4069
# Epoch 44/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1357 - mae: 0.2549
# Epoch 45/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2494 - mae: 0.3168
# Epoch 46/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2228 - mae: 0.2777
# Epoch 47/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2171 - mae: 0.2969
# Epoch 48/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2718 - mae: 0.3393
# Epoch 49/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3074 - mae: 0.3287
# Epoch 50/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2362 - mae: 0.2839
# Epoch 51/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3111 - mae: 0.3712
# Epoch 52/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2378 - mae: 0.3131
# Epoch 53/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3134 - mae: 0.3267
# Epoch 54/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1862 - mae: 0.2996
# Epoch 55/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2694 - mae: 0.3490
# Epoch 56/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3073 - mae: 0.3204
# Epoch 57/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1771 - mae: 0.2777
# Epoch 58/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1585 - mae: 0.2525
# Epoch 59/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.6034 - mae: 0.4048
# Epoch 60/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1376 - mae: 0.2423
# Epoch 61/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1239 - mae: 0.2409
# Epoch 62/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1974 - mae: 0.2873
# Epoch 63/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4039 - mae: 0.2994
# Epoch 64/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2170 - mae: 0.3107
# Epoch 65/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4084 - mae: 0.3691
# Epoch 66/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4551 - mae: 0.3924
# Epoch 67/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1637 - mae: 0.2518
# Epoch 68/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2048 - mae: 0.2923
# Epoch 69/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3343 - mae: 0.3363
# Epoch 70/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.6794 - mae: 0.4250
# Epoch 71/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3947 - mae: 0.3429
# Epoch 72/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3462 - mae: 0.3204
# Epoch 73/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.0951 - mae: 0.2447
# Epoch 74/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2542 - mae: 0.3243
# Epoch 75/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2419 - mae: 0.2769
# Epoch 76/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2075 - mae: 0.2633
# Epoch 77/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1388 - mae: 0.2284
# Epoch 78/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1279 - mae: 0.2325
# Epoch 79/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1220 - mae: 0.2311
# Epoch 80/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4349 - mae: 0.3788
# Epoch 81/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5953 - mae: 0.4036
# Epoch 82/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2442 - mae: 0.2720
# Epoch 83/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.0986 - mae: 0.1978
# Epoch 84/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2924 - mae: 0.2964
# Epoch 85/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2597 - mae: 0.3129
# Epoch 86/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1926 - mae: 0.2785
# Epoch 87/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1381 - mae: 0.2332
# Epoch 88/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1940 - mae: 0.3169
# Epoch 89/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1531 - mae: 0.2553
# Epoch 90/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1367 - mae: 0.2262
# Epoch 91/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1854 - mae: 0.2776
# Epoch 92/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3377 - mae: 0.3219
# Epoch 93/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1592 - mae: 0.2398
# Epoch 94/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1826 - mae: 0.2538
# Epoch 95/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.0966 - mae: 0.1871
# Epoch 96/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2008 - mae: 0.2753
# Epoch 97/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2683 - mae: 0.2958
# Epoch 98/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3859 - mae: 0.3188
# Epoch 99/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3174 - mae: 0.3021
# Epoch 100/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3229 - mae: 0.3194
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7f6d3d6d3dd0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 [==============================] - 0s 7ms/step - loss: 0.4185 - mae: 0.3731
# processing fold # 3
# Epoch 1/100
# 106/106 [==============================] - 1s 1ms/step - loss: 0.8695 - mae: 0.6589
# Epoch 2/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.8618 - mae: 0.6595
# Epoch 3/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.8666 - mae: 0.6446
# Epoch 4/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.8454 - mae: 0.6106
# Epoch 5/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.6158 - mae: 0.5469
# Epoch 6/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.6114 - mae: 0.5595
# Epoch 7/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.7623 - mae: 0.5396
# Epoch 8/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.6794 - mae: 0.5670
# Epoch 9/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.6350 - mae: 0.5374
# Epoch 10/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3265 - mae: 0.4021
# Epoch 11/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2540 - mae: 0.3946
# Epoch 12/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5091 - mae: 0.5079
# Epoch 13/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4087 - mae: 0.4628
# Epoch 14/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3988 - mae: 0.4350
# Epoch 15/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4461 - mae: 0.4322
# Epoch 16/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4014 - mae: 0.4050
# Epoch 17/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3458 - mae: 0.3957
# Epoch 18/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4569 - mae: 0.4533
# Epoch 19/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4850 - mae: 0.4937
# Epoch 20/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4046 - mae: 0.4653
# Epoch 21/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4379 - mae: 0.4256
# Epoch 22/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4217 - mae: 0.4358
# Epoch 23/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4956 - mae: 0.4373
# Epoch 24/100
# 106/106 [==============================] - 0s 2ms/step - loss: 0.2944 - mae: 0.3964
# Epoch 25/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3732 - mae: 0.3675
# Epoch 26/100
# 106/106 [==============================] - 0s 2ms/step - loss: 0.2518 - mae: 0.3528
# Epoch 27/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3197 - mae: 0.3659
# Epoch 28/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4015 - mae: 0.3929
# Epoch 29/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3224 - mae: 0.3823
# Epoch 30/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1952 - mae: 0.2962
# Epoch 31/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3203 - mae: 0.3359
# Epoch 32/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4241 - mae: 0.4440
# Epoch 33/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2533 - mae: 0.3457
# Epoch 34/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3018 - mae: 0.3581
# Epoch 35/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5305 - mae: 0.4701
# Epoch 36/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5075 - mae: 0.4565
# Epoch 37/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4316 - mae: 0.4341
# Epoch 38/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2988 - mae: 0.3947
# Epoch 39/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4024 - mae: 0.3865
# Epoch 40/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4174 - mae: 0.3549
# Epoch 41/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.9206 - mae: 0.5155
# Epoch 42/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2871 - mae: 0.3728
# Epoch 43/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2581 - mae: 0.3402
# Epoch 44/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4515 - mae: 0.3735
# Epoch 45/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3758 - mae: 0.3792
# Epoch 46/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3350 - mae: 0.3399
# Epoch 47/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3940 - mae: 0.3814
# Epoch 48/100
# 106/106 [==============================] - 0s 2ms/step - loss: 0.3807 - mae: 0.4131
# Epoch 49/100
# 106/106 [==============================] - 0s 2ms/step - loss: 0.3615 - mae: 0.4014
# Epoch 50/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1448 - mae: 0.2926
# Epoch 51/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2399 - mae: 0.3458
# Epoch 52/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3411 - mae: 0.3590
# Epoch 53/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5060 - mae: 0.4689
# Epoch 54/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3090 - mae: 0.3799
# Epoch 55/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3740 - mae: 0.4230
# Epoch 56/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3254 - mae: 0.4119
# Epoch 57/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1622 - mae: 0.2920
# Epoch 58/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2905 - mae: 0.3681
# Epoch 59/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2141 - mae: 0.3057
# Epoch 60/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4995 - mae: 0.4254
# Epoch 61/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3049 - mae: 0.3596
# Epoch 62/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2686 - mae: 0.3214
# Epoch 63/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4401 - mae: 0.4147
# Epoch 64/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.6482 - mae: 0.4570
# Epoch 65/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2161 - mae: 0.2987
# Epoch 66/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4268 - mae: 0.3952
# Epoch 67/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2598 - mae: 0.3011
# Epoch 68/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2466 - mae: 0.3273
# Epoch 69/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1955 - mae: 0.2930
# Epoch 70/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1724 - mae: 0.2817
# Epoch 71/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.9281 - mae: 0.4802
# Epoch 72/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2918 - mae: 0.3323
# Epoch 73/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1580 - mae: 0.2875
# Epoch 74/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3787 - mae: 0.3365
# Epoch 75/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3484 - mae: 0.3727
# Epoch 76/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3269 - mae: 0.3689
# Epoch 77/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2353 - mae: 0.3210
# Epoch 78/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2504 - mae: 0.2970
# Epoch 79/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3240 - mae: 0.3294
# Epoch 80/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2223 - mae: 0.2961
# Epoch 81/100
# 106/106 [==============================] - 0s 2ms/step - loss: 0.2760 - mae: 0.3381
# Epoch 82/100
# 106/106 [==============================] - 0s 2ms/step - loss: 0.2666 - mae: 0.3106
# Epoch 83/100
# 106/106 [==============================] - 0s 2ms/step - loss: 0.1469 - mae: 0.2756
# Epoch 84/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2403 - mae: 0.3223
# Epoch 85/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2438 - mae: 0.3207
# Epoch 86/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1684 - mae: 0.2733
# Epoch 87/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2287 - mae: 0.2852
# Epoch 88/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2368 - mae: 0.2871
# Epoch 89/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3076 - mae: 0.3066
# Epoch 90/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2976 - mae: 0.3622
# Epoch 91/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1981 - mae: 0.2845
# Epoch 92/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4147 - mae: 0.3594
# Epoch 93/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5449 - mae: 0.4087
# Epoch 94/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3556 - mae: 0.3735
# Epoch 95/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2912 - mae: 0.3209
# Epoch 96/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2820 - mae: 0.2988
# Epoch 97/100
# 106/106 [==============================] - 0s 2ms/step - loss: 0.2377 - mae: 0.2755
# Epoch 98/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2619 - mae: 0.3109
# Epoch 99/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1172 - mae: 0.2290
# Epoch 100/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2410 - mae: 0.2937
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7f6d3c52fdd0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 [==============================] - 0s 7ms/step - loss: 0.1357 - mae: 0.2505

# %% [markdown]
# # Scores

# %%
all_scores_relu
# Out:
# [0.33395570516586304,
#  0.3573090732097626,
#  0.3708646297454834,
#  0.3802023231983185]

# %%
all_scores_tanh
# Out:
# [0.36811959743499756,
#  0.4042193293571472,
#  0.4945627450942993,
#  0.20370478928089142]

# %%
all_scores_regular
# Out:
# [0.3811265528202057,
#  0.27551931142807007,
#  0.2743983268737793,
#  0.39512020349502563]

# %%
all_scores_drop
# Out:
# [0.4023531377315521,
#  0.4575016498565674,
#  0.3730921447277069,
#  0.25053030252456665]

# %% [markdown]
# # training on the training data

# %%
model_tanh = build_model('tanh')
model_tanh.fit(train, train_l,epochs= 100, batch_size=1, verbose=0)
test_mse_score, test_mae_score = model_tanh.evaluate(test, test_l)
# Out:
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7f6d3d6e5290> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 [==============================] - 0s 10ms/step - loss: 0.1129 - mae: 0.2469

# %%
model_relu = build_model('relu')
model_relu.fit(train, train_l,epochs= 100, batch_size=1, verbose=0)
test_mse_score, test_mae_score = model_relu.evaluate(test, test_l)
# Out:
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7f6d3a0a0320> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 [==============================] - 0s 14ms/step - loss: 0.1079 - mae: 0.2567

# %%
model_regular = build_model_regular('relu')
model_regular.fit(train, train_l,epochs= 100, batch_size=1, verbose=0)
test_mse_score, test_mae_score = model_regular.evaluate(test, test_l)
# Out:
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7f6d3a022dd0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 [==============================] - 0s 7ms/step - loss: 0.1691 - mae: 0.2680

# %%
model_drop = build_model_drop('relu')
model_drop.fit(train, train_l,epochs= 100, batch_size=1, verbose=0)
test_mse_score, test_mae_score = model_drop.evaluate(test, test_l)
# Out:
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7f6d40f18cb0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 [==============================] - 0s 10ms/step - loss: 0.1297 - mae: 0.2674

# %% [markdown]
# # Prediction Section

# %%
test_l
# Out:
# array([ 0.01414832,  0.3725343 ,  1.3658801 ,  2.122337  , -1.004718  ,
#        -0.7045773 , -0.5886972 , -0.97443527, -0.763189  , -0.52312535,
#        -0.05301089, -0.3704908 , -0.5449216 , -0.80397296, -0.5536523 ,
#        -0.26059392,  0.6062484 ,  1.4864004 ,  2.5404336 ,  3.367835  ,
#        -0.8779702 , -0.09159691,  0.18192424, -0.7802841 , -0.50065756,
#        -0.9622245 , -0.6813769 , -0.5409531 ,  0.01463675,  0.12453365,
#         0.46643507, -0.1806134 ,  0.2687428 ,  0.4299249 ,  0.45129374,
#        -0.07511237,  2.3382235 ,  2.200547  , -0.49870384,  0.20280465,
#         0.26019526, -0.68430746, -0.7224051 , -0.65524584, -0.98066276,
#        -0.7889537 , -0.7547636 , -0.6888255 , -0.6277716 , -0.4983375 ,
#        -0.6020069 , -0.4139611 , -0.22347318, -0.54107517,  0.28217462,
#        -0.68430746, -0.6574438 , -0.59638995, -0.01027321,  0.056886  ,
#        -0.1329914 , -0.05362143,  0.3181964 ,  0.6155285 ], dtype=float32)

# %%
def predict(model, m):
  print(f" the actual price was : {test_l[m]* std_label + mean_label} " )
  return(f" the predicted price was : {(model.predict(test[m:m+1].reshape(1,test.shape[1]))) * std_label + mean_label} ")

# %%
x_tanh = predict(model_tanh,2)
x_tanh
# Out:
#  the actual price was : 24565.000309357743
# ' the predicted price was : [[20276.049]] '

# %%
x_relu = predict(model_relu,2)
x_relu
# Out:
#  the actual price was : 24565.000309357743
# ' the predicted price was : [[22551.004]] '

# %%
x_regular = predict(model_regular,2)
x_regular
# Out:
#  the actual price was : 24565.000309357743
# ' the predicted price was : [[19910.5]] '

# %%
x_drop = predict(model_drop,2)
x_drop
# Out:
#  the actual price was : 24565.000309357743
# ' the predicted price was : [[21640.121]] '

# %%
def plot_fn(mod):
  y_true = test_l* std_label + mean_label
  y_pred = mod.predict(test) * std_label + mean_label
  return y_true , y_pred.flatten()

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
def plotting(mod, label):
  y_true, y_pred = plot_fn(mod)
  coef = np.polyfit(y_true,y_pred,1)
  poly1d_fn = np.poly1d(coef) 
  # poly1d_fn is now a function which takes in x and returns an estimate for y
  plt.figure()
  plt.plot(y_true,y_pred, 'yo', y_true, poly1d_fn(y_true), '--k')
  plt.title(label)
  plt.xlabel('Thousand Dollar True' )
  plt.ylabel('Thousand Dollar Predictions' )
  plt.xlim(0, 50000)
  plt.ylim(0, 50000)

# %%
plot_list = []
for i,j in enumerate([model_relu, model_tanh, model_regular, model_drop]):
  list_name = ['model_relu', 'model_tanh', 'model_regular', 'model_drop']
  plot_list.append(plotting(j,list_name[i]))
# Out:
# WARNING:tensorflow:5 out of the last 5 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f6d40e9c680> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 7 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f6d55ed1200> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:7 out of the last 9 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f6d40f18290> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:8 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f6d3a16d830> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
